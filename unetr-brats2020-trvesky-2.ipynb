# %%
# !pip install monai==0.6
# Out:
# Collecting monai==0.6
#   Downloading monai-0.6.0-202107081903-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: torch>=1.5 in /opt/conda/lib/python3.10/site-packages (from monai==0.6) (2.1.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from monai==0.6) (1.26.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.5->monai==0.6) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.5->monai==0.6) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.5->monai==0.6) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.5->monai==0.6) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.5->monai==0.6) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.5->monai==0.6) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.5->monai==0.6) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.5->monai==0.6) (1.3.0)
# Downloading monai-0.6.0-202107081903-py3-none-any.whl (584 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.8/584.8 kB 19.0 MB/s eta 0:00:00
# Installing collected packages: monai
# Successfully installed monai-0.6.0

# %%
import os
import sys
import time
import math
import copy
import torch
from torch import nn as nn
import numpy as np
from matplotlib import pyplot as plt
from easydict import EasyDict
from typing import List, Dict, Union, Sequence, Callable

from monai.data import DataLoader, CacheDataset, decollate_batch
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.transforms import (
    Activations,
    Activationsd,
    AsDiscrete,
    AsDiscreted,
    Compose,
    LoadImaged,
    MapTransform,
    NormalizeIntensityd,
    Orientationd,
    Randomizable,
    Resized,
    Spacingd,
    EnsureTyped,
    EnsureChannelFirstd,
    ToTensord,
)
from monai.utils import set_determinism
# Out:
# 2024-07-02 12:46:42.837908: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-02 12:46:42.838047: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-02 12:46:42.987638: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Setup configuration

# %%
cfg = EasyDict()
cfg.epoch = 100
cfg.learning_rate = 1e-4
cfg.weight_decay = 1e-5
cfg.patience = 30

cfg.unetr = EasyDict()
cfg.unetr.img_shape = (96, 96, 96)
cfg.unetr.input_dim = 4
cfg.unetr.output_dim = 3
cfg.unetr.patch_size = 16
cfg.unetr.embed_dim = 768
cfg.unetr.num_layers = 12
cfg.unetr.num_heads = 12
cfg.unetr.mlp_dim = 2048
cfg.unetr.extract_layers = [3, 6, 9, 12]

# %% [markdown]
# # Setup data directory

# %%
root_dir = "/kaggle/input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData"
output_dir = "/kaggle/working/"

# %% [markdown]
# # Set deterministic training for reproducibility

# %%
set_determinism(seed=0)

# %% [markdown]
# # Conv blocks classes

# %%
class SingleDeconv3DBlock(nn.Module):
    '''
    The green box in the architecture
    '''
    def __init__(self, in_planes, out_planes):
        super().__init__()
        self.block = nn.ConvTranspose3d(in_planes, out_planes, kernel_size=2, stride=2, padding=0, output_padding=0)

    def forward(self, x):
        return self.block(x)

# %%
class SingleConv3DBlock(nn.Module):
    '''
    The gray box in the architecture
    '''
    def __init__(self, in_planes, out_planes, kernel_size):
        super().__init__()
        self.block = nn.Conv3d(in_planes, out_planes, kernel_size=kernel_size, stride=1,
                               padding=((kernel_size - 1) // 2))

    def forward(self, x):
        return self.block(x)

# %%
class Conv3DBlock(nn.Module):
    '''
    The yellow box in the architecture
    Cnv3d 3x3x3 + Batch Normalization + ReLU
    '''
    def __init__(self, in_planes, out_planes, kernel_size=3):
        super().__init__()
        self.block = nn.Sequential(
            SingleConv3DBlock(in_planes, out_planes, kernel_size),
            nn.BatchNorm3d(out_planes),
            nn.ReLU(True)
        )

    def forward(self, x):
        return self.block(x)

# %%
class Deconv3DBlock(nn.Module):
    '''
    The blue box in the architecture
    Deconv 2x2x2 + Conv 3x3x3 + Batch Normalization + ReLU
    '''
    def __init__(self, in_planes, out_planes, kernel_size=3):
        super().__init__()
        self.block = nn.Sequential(
            SingleDeconv3DBlock(in_planes, out_planes),
            SingleConv3DBlock(out_planes, out_planes, kernel_size),
            nn.BatchNorm3d(out_planes),
            nn.ReLU(True)
        )

    def forward(self, x):
        return self.block(x)

# %% [markdown]
# # Transformer classes

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, embed_dim, dropout):
        super().__init__()
        self.num_attention_heads = num_heads
        self.attention_head_size = int(embed_dim / num_heads)
        self.all_head_size = self.num_attention_heads * self.attention_head_size
        self.query = nn.Linear(embed_dim, self.all_head_size)
        self.key = nn.Linear(embed_dim, self.all_head_size)
        self.value = nn.Linear(embed_dim, self.all_head_size)

        self.out = nn.Linear(embed_dim, embed_dim)
        self.attn_dropout = nn.Dropout(dropout)
        self.proj_dropout = nn.Dropout(dropout)

        self.softmax = nn.Softmax(dim=-1)

        self.vis = False

    def transpose_for_scores(self, x):
        new_x_shape = x.size()[:-1] + (self.num_attention_heads, self.attention_head_size)
        x = x.view(*new_x_shape)
        return x.permute(0, 2, 1, 3)

    def forward(self, hidden_states):
        mixed_query_layer = self.query(hidden_states)
        mixed_key_layer = self.key(hidden_states)
        mixed_value_layer = self.value(hidden_states)

        query_layer = self.transpose_for_scores(mixed_query_layer)
        key_layer = self.transpose_for_scores(mixed_key_layer)
        value_layer = self.transpose_for_scores(mixed_value_layer)

        attention_scores = torch.matmul(query_layer, key_layer.transpose(-1, -2))
        attention_scores = attention_scores / math.sqrt(self.attention_head_size)
        attention_probs = self.softmax(attention_scores)
        weights = attention_probs if self.vis else None
        attention_probs = self.attn_dropout(attention_probs)

        context_layer = torch.matmul(attention_probs, value_layer)
        context_layer = context_layer.permute(0, 2, 1, 3).contiguous()
        new_context_layer_shape = context_layer.size()[:-2] + (self.all_head_size,)
        context_layer = context_layer.view(*new_context_layer_shape)
        attention_output = self.out(context_layer)

        attention_output = self.proj_dropout(attention_output)
        return attention_output, weights

# %%
class MLP(nn.Module):
    def __init__(self, embedding_dim, mlp_dim):
        super().__init__()

        self.mlp = nn.Sequential(
            nn.Linear(embedding_dim, mlp_dim),
            nn.GELU(),
            nn.Dropout(0.1),
            nn.Linear(mlp_dim, embedding_dim),
            nn.Dropout(0.1)
        )

    def forward(self, x):
        x = self.mlp(x)
        return x

# %%
class Embeddings(nn.Module):
    def __init__(self, input_dim, embed_dim, cube_size, patch_size, dropout):
        super().__init__()
        self.n_patches = int((cube_size[0] * cube_size[1] * cube_size[2]) / (patch_size * patch_size * patch_size))
        self.patch_size = patch_size
        self.embed_dim = embed_dim
        # They used convolution operation for making patches. Where kernel size is the patch_size, anstride is patch_size.
        # In normal ViT, there is a flattening layer followed by a Dense layer"
        self.patch_embeddings = nn.Conv3d(in_channels=input_dim, out_channels=embed_dim,
                                          kernel_size=patch_size, stride=patch_size)
        self.position_embeddings = nn.Parameter(torch.zeros(1, self.n_patches, embed_dim))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.patch_embeddings(x)
        x = x.flatten(2) # the output of conv layer(a matrix) is then flattened.
        x = x.transpose(-1, -2)
        embeddings = x + self.position_embeddings
        embeddings = self.dropout(embeddings)
        return embeddings

# %%
class TransformerBlock(nn.Module):
    def __init__(self, embed_dim, num_heads, dropout, cube_size, patch_size):
        super().__init__()
        self.attention_norm = nn.LayerNorm(embed_dim, eps=1e-6)
        self.mlp_norm = nn.LayerNorm(embed_dim, eps=1e-6)
        self.mlp_dim = int((cube_size[0] * cube_size[1] * cube_size[2]) / (patch_size * patch_size * patch_size))
        self.mlp = MLP(embed_dim, cfg.unetr.mlp_dim)
        self.attn = MultiHeadAttention(num_heads, embed_dim, dropout)

    def forward(self, x):
        h = x
        x = self.attention_norm(x)
        x, weights = self.attn(x)
        x = x + h
        
        h = x
        x = self.mlp_norm(x)
        x = self.mlp(x)
        x = x + h
        
        return x, weights

# %%
class Transformer(nn.Module):
    def __init__(self, input_dim, embed_dim, cube_size, patch_size, num_heads, num_layers, dropout, extract_layers):
        super().__init__()
        self.embeddings = Embeddings(input_dim, embed_dim, cube_size, patch_size, dropout)
        self.layer = nn.ModuleList()
        self.encoder_norm = nn.LayerNorm(embed_dim, eps=1e-6)
        self.extract_layers = extract_layers
        for _ in range(num_layers):
            layer = TransformerBlock(embed_dim, num_heads, dropout, cube_size, patch_size)
            self.layer.append(copy.deepcopy(layer))

    def forward(self, x):
        extract_layers = []
        hidden_states = self.embeddings(x)

        for depth, layer_block in enumerate(self.layer):
            hidden_states, _ = layer_block(hidden_states)
            if depth + 1 in self.extract_layers:
                extract_layers.append(hidden_states)

        return extract_layers

# %% [markdown]
# # UNETR architecture class

# %%
class UNETR(nn.Module):
    def __init__(self, img_shape=cfg.unetr.img_shape, input_dim=cfg.unetr.input_dim, output_dim=cfg.unetr.output_dim, embed_dim=cfg.unetr.embed_dim, patch_size=cfg.unetr.patch_size, num_heads=cfg.unetr.num_heads, dropout=0.1):
        super().__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.embed_dim = embed_dim
        self.img_shape = img_shape
        self.patch_size = patch_size
        self.num_heads = num_heads
        self.dropout = dropout
        self.num_layers = cfg.unetr.num_layers
        self.ext_layers = cfg.unetr.extract_layers

        self.patch_dim = [int(x / patch_size) for x in img_shape]

        # Transformer Encoder
        self.transformer = \
            Transformer(
                input_dim=input_dim,
                embed_dim=embed_dim,
                cube_size=img_shape,
                patch_size=patch_size,
                num_heads=num_heads,
                num_layers=self.num_layers,
                dropout=dropout,
                extract_layers=self.ext_layers
            )

        # U-Net Decoder
        self.decoder0 = \
            nn.Sequential(
                Conv3DBlock(input_dim, 32, 3),
                Conv3DBlock(32, 64, 3)
            )

        self.decoder3 = \
            nn.Sequential(
                Deconv3DBlock(embed_dim, 512),
                Deconv3DBlock(512, 256),
                Deconv3DBlock(256, 128)
            )

        self.decoder6 = \
            nn.Sequential(
                Deconv3DBlock(embed_dim, 512),
                Deconv3DBlock(512, 256),
            )

        self.decoder9 = \
            Deconv3DBlock(embed_dim, 512)

        self.decoder12_upsampler = \
            SingleDeconv3DBlock(embed_dim, 512)

        self.decoder9_upsampler = \
            nn.Sequential(
                Conv3DBlock(1024, 512),
                Conv3DBlock(512, 512),
                Conv3DBlock(512, 512),
                SingleDeconv3DBlock(512, 256)
            )

        self.decoder6_upsampler = \
            nn.Sequential(
                Conv3DBlock(512, 256),
                Conv3DBlock(256, 256),
                SingleDeconv3DBlock(256, 128)
            )

        self.decoder3_upsampler = \
            nn.Sequential(
                Conv3DBlock(256, 128),
                Conv3DBlock(128, 128),
                SingleDeconv3DBlock(128, 64)
            )

        self.decoder0_header = \
            nn.Sequential(
                Conv3DBlock(128, 64),
                Conv3DBlock(64, 64),
                SingleConv3DBlock(64, output_dim, 1)
            )

    def forward(self, x):
        z = self.transformer(x)
        z0, z3, z6, z9, z12 = x, *z
        z3 = z3.transpose(-1, -2).view(-1, self.embed_dim, *self.patch_dim)
        z6 = z6.transpose(-1, -2).view(-1, self.embed_dim, *self.patch_dim)
        z9 = z9.transpose(-1, -2).view(-1, self.embed_dim, *self.patch_dim)
        z12 = z12.transpose(-1, -2).view(-1, self.embed_dim, *self.patch_dim)

        z12 = self.decoder12_upsampler(z12)
        z9 = self.decoder9(z9)
        z9 = self.decoder9_upsampler(torch.cat([z9, z12], dim=1))
        z6 = self.decoder6(z6)
        z6 = self.decoder6_upsampler(torch.cat([z6, z9], dim=1))
        z3 = self.decoder3(z3)
        z3 = self.decoder3_upsampler(torch.cat([z3, z6], dim=1))
        z0 = self.decoder0(z0)
        output = self.decoder0_header(torch.cat([z0, z3], dim=1))
        return output

# %% [markdown]
# # Utility functions

# %%
def plot_data_distribution(num_train: int, num_val: int, num_test: int):
    """Plot number of data for train-set, val-set, and test-set after splitted"""

    # Create the bar chart
    bars = plt.bar(["Train", "Val", "Test"],
            [num_train, num_val, num_test], align='center', color=['green', 'red', 'blue'])

    # Add the data value on top of each bar
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval + 0.05, yval, ha='center', va='bottom')

    plt.ylabel('Number of images')
    plt.title('Data distribution')

    plt.show()


def load_datalist(
    root_dir: str
) -> List[Dict]:
    """
    Load image/label paths of dataset
    """
    
    datalist = []
    for data in os.listdir(root_dir):
        data_dir_path = os.path.join(root_dir, data)
        if os.path.isdir(data_dir_path):
            model_scans = ["flair", "t1", "t1ce", "t2"]
            image_paths = [os.path.join(data_dir_path, f"{data}_{model}.nii") for model in model_scans]
            label_path = os.path.join(data_dir_path, f"{data}_seg.nii")

            if (all(os.path.exists(path) for path in [*image_paths, label_path])):
                datalist.append({
                    "image": image_paths,
                    "label": label_path
                })

    return datalist


class ConvertToMultiChannelBasedOnBratsClassesd(MapTransform):
    """
    Convert labels to multi channels based on brats classes:
    label 1 is the necrotic and non-enhancing tumor core
    label 2 is the peritumoral edema
    label 4 is the GD-enhancing tumor
    The possible classes are TC (Tumor core), WT (Whole tumor)
    and ET (Enhancing tumor).

    """

    def __call__(self, data):
        d = dict(data)
        for key in self.keys:
            result = []
            # merge label 1 and label 4 to construct TC
            result.append(np.logical_or(d[key] == 1, d[key] == 4))
            # merge labels 1, 2 and 4 to construct WT
            result.append(
                np.logical_or(
                    np.logical_or(d[key] == 1, d[key] == 4), d[key] == 2
                )
            )
            # label 4 is ET
            result.append(d[key] == 4)
            d[key] = np.stack(result, axis=0).astype("float32")
        return d
    
    
class BratsDataset(Randomizable, CacheDataset):
    """
    Generate items for training, validation or test.
    """

    def __init__(
        self,
        root_dir: str,
        section: str,
        transform: Union[Sequence[Callable], Callable] = (),
        val_frac: float = 0.15,
        test_frac: float = 0.05,
        seed: int = 0,
        cache_num: int = sys.maxsize,
        cache_rate: float = 1.0,
        num_workers: int = 0,
    ) -> None:
        if not os.path.isdir(root_dir) or not os.path.exists(root_dir):
            raise RuntimeError(
                f"Cannot find dataset directory: {root_dir}."
            )

        self.section = section
        self.val_frac = val_frac
        self.test_frac = test_frac
        self.set_random_state(seed=seed)
        self.indices: np.ndarray = np.array([])
        
        data = self._generate_data_list(root_dir)
        CacheDataset.__init__(
            self, data, transform, cache_num=cache_num, cache_rate=cache_rate, num_workers=num_workers
        )

    def get_indices(self) -> np.ndarray:
        """
        Get the indices of datalist used in this dataset.
        """
        return self.indices

    def randomize(self, data: List[int]) -> None:
        self.R.shuffle(data)

    def _generate_data_list(self, root_dir: str) -> List[Dict]:
        datalist = load_datalist(root_dir)
        return self._split_datalist(datalist)

    def _split_datalist(self, datalist: List[Dict]) -> List[Dict]:
        length = len(datalist)
        indices = np.arange(length)
        self.randomize(indices)

        val_length = int(length * self.val_frac)
        test_length = int(length * self.test_frac)
        if self.section == "training":
            self.indices = indices[val_length+test_length:]
        elif self.section == "validation":
            self.indices = indices[test_length:val_length+test_length]
        else:
            self.indices = indices[:test_length]

        return [datalist[i] for i in self.indices]

# %% [markdown]
# # Setup transforms for training and validation

# %%
transform = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys="image"),
        EnsureTyped(keys=["image", "label"]),
        ConvertToMultiChannelBasedOnBratsClassesd(keys="label"),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(
            keys=["image", "label"],
            pixdim=(1.0, 1.0, 1.0),
            mode=("bilinear", "nearest"),
        ),
        Resized(keys=["image", "label"], spatial_size=cfg.unetr.img_shape, mode="nearest"),
        NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
        ToTensord(keys=["image", "label"]),
    ]
)

# %% [markdown]
# # Loading dataset

# %%
train_ds = BratsDataset(
    root_dir=root_dir,
    section="training",
    transform=transform,
    cache_rate=0.0,
    num_workers=4
)
train_loader = DataLoader(train_ds, batch_size=1, shuffle=True, num_workers=4)
val_ds = BratsDataset(
    root_dir=root_dir,
    section="validation",
    transform=transform,
    cache_rate=0.0,
    num_workers=4
)
val_loader = DataLoader(val_ds, batch_size=1, shuffle=False, num_workers=4)

# %% [markdown]
# # Check data shape and visualize

# %%
image_channels = ['FLAIR', 'T1w', 'T1gd', 'T2w']
label_channels = ['Tumor Core', 'Whole Tumor', 'Enhancing Tumor']

# pick one image from BratsDataset to visualize and check the 4 channels
val_data_example = val_ds[1]
print(f"image shape: {val_data_example['image'].shape}")
plt.figure("image", (24, 6))
for i in range(len(image_channels)):
    plt.subplot(1, 4, i + 1)
    plt.title(f"{image_channels[i]} image", weight='bold')
    plt.imshow(val_data_example["image"][i, :, :, val_data_example['image'].shape[-1] // 2], cmap="gray")
plt.show()

# also visualize the 3 channels label corresponding to this image
print(f"label shape: {val_data_example['label'].shape}")
plt.figure("label", (18, 6))
for i in range(len(label_channels)):
    plt.subplot(1, 3, i + 1)
    plt.title(f"{label_channels[i]} label", weight='bold')
    plt.imshow(val_data_example["label"][i, :, :, val_data_example['image'].shape[-1] // 2])
plt.show()
# Out:
# image shape: torch.Size([4, 96, 96, 96])
# label shape: torch.Size([3, 96, 96, 96])

# %% [markdown]
# # Check number of data
#
# Check number of data used for training / testing / validation

# %%
val_frac = val_ds.val_frac
test_frac = val_ds.test_frac

num_train = len(train_ds)
num_val = len(val_ds)
num_test = int(test_frac * num_val / val_frac)

plot_data_distribution(num_train, num_val, num_test)

# %% [markdown]
# # Create Model, Loss, Optimizer

# %%
import torch
from monai.losses import TverskyLoss  # Assuming TverskyLoss is from MONAI

val_interval = 1
VAL_AMP = True

# Check if CUDA (GPU support) is available
device = torch.device("cpu:0")
if torch.cuda.is_available():
    device = torch.device("cuda:0")
print(device)

model = UNETR(
    img_shape=cfg.unetr.img_shape,
    input_dim=cfg.unetr.input_dim,
    output_dim=cfg.unetr.output_dim,
    embed_dim=cfg.unetr.embed_dim,
    patch_size=cfg.unetr.patch_size,
    num_heads=cfg.unetr.num_heads,
    dropout=0.1
).to(device)

# Change the loss function from DiceLoss to TverskyLoss
loss_function = TverskyLoss(smooth_nr=0, smooth_dr=1e-5, alpha=0.5, beta=0.5, to_onehot_y=False, sigmoid=True)

optimizer = torch.optim.Adam(model.parameters(), cfg.learning_rate, weight_decay=cfg.weight_decay)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.epoch)
dice_metric = DiceMetric(include_background=True, reduction="mean")
dice_metric_batch = DiceMetric(include_background=True, reduction="mean_batch")

post_trans = Compose([Activations(sigmoid=True), AsDiscrete(threshold_values=True, logit_thresh=0.5)])

# define inference method
def inference(input):
    def _compute(input):
        return sliding_window_inference(
            inputs=input,
            roi_size=cfg.unetr.img_shape,
            sw_batch_size=1,
            predictor=model,
        )

    if VAL_AMP:
        with torch.cuda.amp.autocast():
            return _compute(input)
    else:
        return _compute(input)

# use amp to accelerate training
scaler = torch.cuda.amp.GradScaler()
# enable cuDNN benchmark
torch.backends.cudnn.benchmark = True
# Out:
# cuda:0

# %% [markdown]
# # Execute a typical PyTorch training process

# %%
training = True
best_metric = -1
best_metric_epoch = -1
not_improved_epoch = 0
epoch_loss_values = []
metric_values = []
metric_values_tc = []
metric_values_wt = []
metric_values_et = []

total_start = time.time()
for epoch in range(cfg.epoch):
    epoch_start = time.time()
    print("-" * 10)
    print(f"epoch {epoch + 1}/{cfg.epoch}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step_start = time.time()
        step += 1
        inputs, labels = (
            batch_data["image"].to(device),
            batch_data["label"].to(device),
        )
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            outputs = model(inputs)
            loss = loss_function(outputs, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        epoch_loss += loss.item()
        print(
            f"{step}/{len(train_ds) // train_loader.batch_size}"
            f", train_loss: {loss.item():.4f}"
            f", step time: {(time.time() - step_start):.4f}"
        )
    lr_scheduler.step()
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                val_outputs = inference(val_inputs)
                val_outputs = [post_trans(i) for i in decollate_batch(val_outputs)]
                dice_metric(y_pred=val_outputs, y=val_labels)
                dice_metric_batch(y_pred=val_outputs, y=val_labels)

            metric = dice_metric.aggregate().item()
            metric_values.append(metric)
            metric_batch = dice_metric_batch.aggregate()
            metric_tc = metric_batch[0].item()
            metric_values_tc.append(metric_tc)
            metric_wt = metric_batch[1].item()
            metric_values_wt.append(metric_wt)
            metric_et = metric_batch[2].item()
            metric_values_et.append(metric_et)
            dice_metric.reset()
            dice_metric_batch.reset()

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                not_improved_epoch = 0
                torch.save(
                    model.state_dict(),
                    os.path.join(output_dir, "best_metric_model.pth"),
                )
                print("saved new best metric model")
            else:
                not_improved_epoch += 1
                if not_improved_epoch >= cfg.patience:
                    training = False
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                f" tc: {metric_tc:.4f} wt: {metric_wt:.4f} et: {metric_et:.4f}"
                f"\nbest mean dice: {best_metric:.4f}"
                f" at epoch: {best_metric_epoch}"
            )
    print(f"time consuming of epoch {epoch + 1} is: {(time.time() - epoch_start):.4f}")
    
    if not training:
        print("Training process is stopped early....")
        break
total_time = time.time() - total_start
# Out:
# ----------
# epoch 1/100
# 1/295, train_loss: 0.9829, step time: 94.3726
# 2/295, train_loss: 0.9826, step time: 1.0376
# 3/295, train_loss: 0.9697, step time: 1.0306
# 4/295, train_loss: 0.9491, step time: 1.0412
# 5/295, train_loss: 0.9918, step time: 1.0359
# 6/295, train_loss: 0.9943, step time: 1.0308
# 7/295, train_loss: 0.9539, step time: 1.0339
# 8/295, train_loss: 0.9552, step time: 1.0473
# 9/295, train_loss: 0.9579, step time: 1.0365
# 10/295, train_loss: 0.9757, step time: 1.0366
# 11/295, train_loss: 0.9675, step time: 1.0384
# 12/295, train_loss: 0.9739, step time: 1.0395
# 13/295, train_loss: 0.9546, step time: 1.0416
# 14/295, train_loss: 0.9906, step time: 1.0602
# 15/295, train_loss: 0.9774, step time: 1.0330
# 16/295, train_loss: 0.9904, step time: 1.0383
# 17/295, train_loss: 0.9754, step time: 1.0325
# 18/295, train_loss: 0.9876, step time: 1.0330
# 19/295, train_loss: 0.9660, step time: 1.0322
# 20/295, train_loss: 0.9952, step time: 1.0299
# 21/295, train_loss: 0.9553, step time: 1.0459
# 22/295, train_loss: 0.9957, step time: 1.0386
# 23/295, train_loss: 0.9729, step time: 1.0699
# 24/295, train_loss: 0.9657, step time: 1.0469
# 25/295, train_loss: 0.9936, step time: 1.0338
# 26/295, train_loss: 0.9687, step time: 1.0356
# 27/295, train_loss: 0.9661, step time: 1.0387
# 28/295, train_loss: 0.9870, step time: 1.0329
# 29/295, train_loss: 0.9708, step time: 1.0330
# 30/295, train_loss: 0.9945, step time: 1.0423
# 31/295, train_loss: 0.9895, step time: 1.1025
# 32/295, train_loss: 0.9906, step time: 1.0310
# 33/295, train_loss: 0.9736, step time: 1.0405
# 34/295, train_loss: 0.9947, step time: 1.0407
# 35/295, train_loss: 0.9690, step time: 1.0598
# 36/295, train_loss: 0.9446, step time: 1.0334
# 37/295, train_loss: 0.9778, step time: 1.0312
# 38/295, train_loss: 0.9756, step time: 1.0531
# 39/295, train_loss: 0.9402, step time: 1.0335
# 40/295, train_loss: 0.9766, step time: 1.0534
# 41/295, train_loss: 0.9764, step time: 1.0493
# 42/295, train_loss: 0.9757, step time: 1.0346
# 43/295, train_loss: 0.9907, step time: 1.0412
# 44/295, train_loss: 0.9855, step time: 1.0341
# 45/295, train_loss: 0.9579, step time: 1.0346
# 46/295, train_loss: 0.9677, step time: 1.0474
# 47/295, train_loss: 0.9575, step time: 1.0372
# 48/295, train_loss: 0.9601, step time: 1.0551
# 49/295, train_loss: 0.9746, step time: 1.0323
# 50/295, train_loss: 0.9482, step time: 1.0337
# 51/295, train_loss: 0.9931, step time: 1.0574
# 52/295, train_loss: 0.9560, step time: 1.0551
# 53/295, train_loss: 0.9710, step time: 1.0589
# 54/295, train_loss: 0.9919, step time: 1.0355
# 55/295, train_loss: 0.9699, step time: 1.0341
# 56/295, train_loss: 0.9980, step time: 1.0346
# 57/295, train_loss: 0.9599, step time: 1.0292
# 58/295, train_loss: 0.9873, step time: 1.0532
# 59/295, train_loss: 0.9712, step time: 1.0339
# 60/295, train_loss: 0.9569, step time: 1.0363
# 61/295, train_loss: 0.9594, step time: 1.0336
# 62/295, train_loss: 0.9721, step time: 1.0327
# 63/295, train_loss: 0.9870, step time: 1.0350
# 64/295, train_loss: 0.9875, step time: 1.0342
# 65/295, train_loss: 0.9940, step time: 1.0350
# 66/295, train_loss: 0.9606, step time: 1.0340
# 67/295, train_loss: 0.9797, step time: 1.0344
# 68/295, train_loss: 0.9739, step time: 1.0334
# 69/295, train_loss: 0.9937, step time: 1.0453
# 70/295, train_loss: 0.9918, step time: 1.0327
# 71/295, train_loss: 0.9892, step time: 1.0324
# 72/295, train_loss: 0.9762, step time: 1.0381
# 73/295, train_loss: 0.9904, step time: 1.0366
# 74/295, train_loss: 0.9621, step time: 1.0332
# 75/295, train_loss: 0.9746, step time: 1.0385
# 76/295, train_loss: 0.9948, step time: 1.0421
# 77/295, train_loss: 0.9647, step time: 1.0624
# 78/295, train_loss: 0.9481, step time: 1.0341
# 79/295, train_loss: 0.9036, step time: 1.0326
# 80/295, train_loss: 0.9935, step time: 1.0431
# 81/295, train_loss: 0.9441, step time: 1.0336
# 82/295, train_loss: 0.9546, step time: 1.0430
# 83/295, train_loss: 0.9891, step time: 1.0380
# 84/295, train_loss: 0.9644, step time: 1.0335
# 85/295, train_loss: 0.9545, step time: 1.0326
# 86/295, train_loss: 0.9692, step time: 1.0402
# 87/295, train_loss: 0.9402, step time: 1.0881
# 88/295, train_loss: 0.9787, step time: 1.0305
# 89/295, train_loss: 0.9422, step time: 1.0401
# 90/295, train_loss: 0.9727, step time: 1.0334
# 91/295, train_loss: 0.9594, step time: 1.0361
# 92/295, train_loss: 0.9449, step time: 1.0460
# 93/295, train_loss: 0.9621, step time: 1.0332
# 94/295, train_loss: 0.9474, step time: 1.0369
# 95/295, train_loss: 0.9439, step time: 1.0743
# 96/295, train_loss: 0.9297, step time: 1.0353
# 97/295, train_loss: 0.9534, step time: 1.0360
# 98/295, train_loss: 0.9761, step time: 1.0333
# 99/295, train_loss: 0.9789, step time: 1.0364
# 100/295, train_loss: 0.9551, step time: 1.0388
# 101/295, train_loss: 0.9536, step time: 1.0398
# 102/295, train_loss: 0.9595, step time: 1.0363
# 103/295, train_loss: 0.9212, step time: 1.0666
# 104/295, train_loss: 0.9745, step time: 1.0350
# 105/295, train_loss: 0.9746, step time: 1.0473
# 106/295, train_loss: 0.9739, step time: 1.0672
# 107/295, train_loss: 0.9587, step time: 1.0530
# 108/295, train_loss: 0.9609, step time: 1.0541
# 109/295, train_loss: 0.9593, step time: 1.0357
# 110/295, train_loss: 0.9593, step time: 1.0892
# 111/295, train_loss: 0.9464, step time: 1.0606
# 112/295, train_loss: 0.9943, step time: 1.0551
# 113/295, train_loss: 0.9780, step time: 1.0370
# 114/295, train_loss: 0.9441, step time: 1.0348
# 115/295, train_loss: 0.9331, step time: 1.0411
# 116/295, train_loss: 0.9762, step time: 1.0323
# 117/295, train_loss: 0.9497, step time: 1.0327
# 118/295, train_loss: 0.9573, step time: 1.0558
# 119/295, train_loss: 0.9793, step time: 1.0381
# 120/295, train_loss: 0.9846, step time: 1.0577
# 121/295, train_loss: 0.9652, step time: 1.0354
# 122/295, train_loss: 0.9576, step time: 1.0295
# 123/295, train_loss: 0.9772, step time: 1.0319
# 124/295, train_loss: 0.9469, step time: 1.0408
# 125/295, train_loss: 0.9411, step time: 1.0772
# 126/295, train_loss: 0.9905, step time: 1.0318
# 127/295, train_loss: 0.9875, step time: 1.0360
# 128/295, train_loss: 0.9874, step time: 1.0320
# 129/295, train_loss: 0.9898, step time: 1.0348
# 130/295, train_loss: 0.9857, step time: 1.0421
# 131/295, train_loss: 0.9555, step time: 1.0453
# 132/295, train_loss: 0.9445, step time: 1.0547
# 133/295, train_loss: 0.9058, step time: 1.0399
# 134/295, train_loss: 0.9810, step time: 1.0531
# 135/295, train_loss: 0.9778, step time: 1.0416
# 136/295, train_loss: 0.9901, step time: 1.0487
# 137/295, train_loss: 0.9398, step time: 1.0354
# 138/295, train_loss: 0.9473, step time: 1.0322
# 139/295, train_loss: 0.9524, step time: 1.0329
# 140/295, train_loss: 0.9754, step time: 1.0473
# 141/295, train_loss: 0.9935, step time: 1.0715
# 142/295, train_loss: 0.9283, step time: 1.0354
# 143/295, train_loss: 0.9798, step time: 1.0520
# 144/295, train_loss: 0.9271, step time: 1.0683
# 145/295, train_loss: 0.9771, step time: 1.0438
# 146/295, train_loss: 0.9821, step time: 1.0342
# 147/295, train_loss: 0.9906, step time: 1.0318
# 148/295, train_loss: 0.9479, step time: 1.0378
# 149/295, train_loss: 0.9902, step time: 1.0555
# 150/295, train_loss: 0.9540, step time: 1.0612
# 151/295, train_loss: 0.9562, step time: 1.0305
# 152/295, train_loss: 0.9298, step time: 1.0530
# 153/295, train_loss: 0.9797, step time: 1.0551
# 154/295, train_loss: 0.9767, step time: 1.0456
# 155/295, train_loss: 0.9770, step time: 1.0350
# 156/295, train_loss: 0.9542, step time: 1.0471
# 157/295, train_loss: 0.9882, step time: 1.0379
# 158/295, train_loss: 0.9744, step time: 1.0627
# 159/295, train_loss: 0.9280, step time: 1.0308
# 160/295, train_loss: 0.9717, step time: 1.0318
# 161/295, train_loss: 0.9574, step time: 1.0324
# 162/295, train_loss: 0.9695, step time: 1.0307
# 163/295, train_loss: 0.9768, step time: 1.0312
# 164/295, train_loss: 0.9906, step time: 1.0308
# 165/295, train_loss: 0.9750, step time: 1.0331
# 166/295, train_loss: 0.9475, step time: 1.0311
# 167/295, train_loss: 0.9944, step time: 1.0352
# 168/295, train_loss: 0.9810, step time: 1.0336
# 169/295, train_loss: 0.9793, step time: 1.0399
# 170/295, train_loss: 0.9229, step time: 1.0416
# 171/295, train_loss: 0.9827, step time: 1.0614
# 172/295, train_loss: 0.9953, step time: 1.0316
# 173/295, train_loss: 0.9907, step time: 1.0321
# 174/295, train_loss: 0.9710, step time: 1.0498
# 175/295, train_loss: 0.9350, step time: 1.0339
# 176/295, train_loss: 0.9632, step time: 1.0672
# 177/295, train_loss: 0.9921, step time: 1.0364
# 178/295, train_loss: 0.9687, step time: 1.0353
# 179/295, train_loss: 0.9627, step time: 1.0577
# 180/295, train_loss: 0.9322, step time: 1.0318
# 181/295, train_loss: 0.9634, step time: 1.0336
# 182/295, train_loss: 0.9873, step time: 1.0313
# 183/295, train_loss: 0.9790, step time: 1.0329
# 184/295, train_loss: 0.9562, step time: 1.0589
# 185/295, train_loss: 0.9946, step time: 1.0406
# 186/295, train_loss: 0.9125, step time: 1.0367
# 187/295, train_loss: 0.9622, step time: 1.0556
# 188/295, train_loss: 0.9388, step time: 1.0330
# 189/295, train_loss: 0.9651, step time: 1.0435
# 190/295, train_loss: 0.9408, step time: 1.0491
# 191/295, train_loss: 0.9911, step time: 1.0404
# 192/295, train_loss: 0.9837, step time: 1.0362
# 193/295, train_loss: 0.9697, step time: 1.0309
# 194/295, train_loss: 0.9539, step time: 1.0339
# 195/295, train_loss: 0.9870, step time: 1.0606
# 196/295, train_loss: 0.9688, step time: 1.0597
# 197/295, train_loss: 0.9648, step time: 1.0348
# 198/295, train_loss: 0.9595, step time: 1.0332
# 199/295, train_loss: 0.9709, step time: 1.0534
# 200/295, train_loss: 0.9777, step time: 1.0452
# 201/295, train_loss: 0.9508, step time: 1.0349
# 202/295, train_loss: 0.9366, step time: 1.0442
# 203/295, train_loss: 0.9571, step time: 1.0317
# 204/295, train_loss: 0.9876, step time: 1.0314
# 205/295, train_loss: 0.9700, step time: 1.0331
# 206/295, train_loss: 0.9758, step time: 1.0326
# 207/295, train_loss: 0.9699, step time: 1.0367
# 208/295, train_loss: 0.9625, step time: 1.0310
# 209/295, train_loss: 0.9714, step time: 1.0396
# 210/295, train_loss: 0.9544, step time: 1.0324
# 211/295, train_loss: 0.9345, step time: 1.0556
# 212/295, train_loss: 0.9579, step time: 1.0361
# 213/295, train_loss: 0.9817, step time: 1.0321
# 214/295, train_loss: 0.9972, step time: 1.0351
# 215/295, train_loss: 0.9677, step time: 1.0360
# 216/295, train_loss: 0.9271, step time: 1.0326
# 217/295, train_loss: 0.9471, step time: 1.0321
# 218/295, train_loss: 0.9164, step time: 1.0393
# 219/295, train_loss: 0.9540, step time: 1.0403
# 220/295, train_loss: 0.9389, step time: 1.0365
# 221/295, train_loss: 0.9511, step time: 1.0552
# 222/295, train_loss: 0.9579, step time: 1.0348
# 223/295, train_loss: 0.9651, step time: 1.0600
# 224/295, train_loss: 0.9582, step time: 1.0341
# 225/295, train_loss: 0.9491, step time: 1.0335
# 226/295, train_loss: 0.9788, step time: 1.0294
# 227/295, train_loss: 0.9341, step time: 1.0315
# 228/295, train_loss: 0.9554, step time: 1.0360
# 229/295, train_loss: 0.9274, step time: 1.0497
# 230/295, train_loss: 0.9473, step time: 1.0422
# 231/295, train_loss: 0.9934, step time: 1.0519
# 232/295, train_loss: 0.9457, step time: 1.0394
# 233/295, train_loss: 0.9144, step time: 1.0739
# 234/295, train_loss: 0.9811, step time: 1.1455
# 235/295, train_loss: 0.9461, step time: 1.0356
# 236/295, train_loss: 0.9166, step time: 1.0323
# 237/295, train_loss: 0.9751, step time: 1.0452
# 238/295, train_loss: 0.9811, step time: 1.0669
# 239/295, train_loss: 0.9610, step time: 1.0530
# 240/295, train_loss: 0.9932, step time: 1.0620
# 241/295, train_loss: 0.9716, step time: 1.0399
# 242/295, train_loss: 0.9828, step time: 1.0339
# 243/295, train_loss: 0.9864, step time: 1.0359
# 244/295, train_loss: 0.9280, step time: 1.0593
# 245/295, train_loss: 0.9791, step time: 1.1096
# 246/295, train_loss: 0.9382, step time: 1.0381
# 247/295, train_loss: 0.9845, step time: 1.0520
# 248/295, train_loss: 0.9452, step time: 1.0471
# 249/295, train_loss: 0.9627, step time: 1.0330
# 250/295, train_loss: 0.9523, step time: 1.0347
# 251/295, train_loss: 0.9493, step time: 1.0550
# 252/295, train_loss: 0.9648, step time: 1.0955
# 253/295, train_loss: 0.9388, step time: 1.0329
# 254/295, train_loss: 0.9516, step time: 1.0451
# 255/295, train_loss: 0.9575, step time: 1.0383
# 256/295, train_loss: 0.9531, step time: 1.0346
# 257/295, train_loss: 0.9066, step time: 1.0328
# 258/295, train_loss: 0.9900, step time: 1.0345
# 259/295, train_loss: 0.9790, step time: 1.0355
# 260/295, train_loss: 0.9282, step time: 1.0636
# 261/295, train_loss: 0.9040, step time: 1.0462
# 262/295, train_loss: 0.9879, step time: 1.0373
# 263/295, train_loss: 0.9630, step time: 1.0435
# 264/295, train_loss: 0.9552, step time: 1.0705
# 265/295, train_loss: 0.9952, step time: 1.0327
# 266/295, train_loss: 0.9518, step time: 1.0333
# 267/295, train_loss: 0.9876, step time: 1.0564
# 268/295, train_loss: 0.9287, step time: 1.0397
# 269/295, train_loss: 0.9759, step time: 1.0400
# 270/295, train_loss: 0.9323, step time: 1.0353
# 271/295, train_loss: 0.9196, step time: 1.0336
# 272/295, train_loss: 0.9740, step time: 1.0322
# 273/295, train_loss: 0.9346, step time: 1.0313
# 274/295, train_loss: 0.9075, step time: 1.0320
# 275/295, train_loss: 0.8885, step time: 1.0538
# 276/295, train_loss: 0.9229, step time: 1.0557
# 277/295, train_loss: 0.9129, step time: 1.0337
# 278/295, train_loss: 0.9889, step time: 1.0417
# 279/295, train_loss: 0.9066, step time: 1.0650
# 280/295, train_loss: 0.9763, step time: 1.0320
# 281/295, train_loss: 0.9290, step time: 1.0346
# 282/295, train_loss: 0.9376, step time: 1.0310
# 283/295, train_loss: 0.9856, step time: 1.0358
# 284/295, train_loss: 0.9309, step time: 1.0343
# 285/295, train_loss: 0.9549, step time: 1.0339
# 286/295, train_loss: 0.9656, step time: 1.0585
# 287/295, train_loss: 0.9702, step time: 1.0338
# 288/295, train_loss: 0.9898, step time: 1.0285
# 289/295, train_loss: 0.9735, step time: 1.0271
# 290/295, train_loss: 0.9653, step time: 1.0278
# 291/295, train_loss: 0.9768, step time: 1.0267
# 292/295, train_loss: 0.9587, step time: 1.0287
# 293/295, train_loss: 0.9482, step time: 1.0281
# 294/295, train_loss: 0.9809, step time: 1.0271
# 295/295, train_loss: 0.9596, step time: 1.0312
# epoch 1 average loss: 0.9642
# saved new best metric model
# current epoch: 1 current mean dice: 0.2591 tc: 0.1331 wt: 0.5141 et: 0.1158
# best mean dice: 0.2591 at epoch: 1
# time consuming of epoch 1 is: 469.9939
# ----------
# epoch 2/100
# 1/295, train_loss: 0.9461, step time: 1.0893
# 2/295, train_loss: 0.9400, step time: 1.1043
# 3/295, train_loss: 0.9538, step time: 1.0545
# 4/295, train_loss: 0.9083, step time: 1.0717
# 5/295, train_loss: 0.9664, step time: 1.0360
# 6/295, train_loss: 0.9934, step time: 1.1192
# 7/295, train_loss: 0.9435, step time: 1.0450
# 8/295, train_loss: 0.9258, step time: 1.1378
# 9/295, train_loss: 0.9235, step time: 1.0316
# 10/295, train_loss: 0.9320, step time: 1.0535
# 11/295, train_loss: 0.9677, step time: 1.0364
# 12/295, train_loss: 0.9157, step time: 1.0503
# 13/295, train_loss: 0.9282, step time: 1.0324
# 14/295, train_loss: 0.9655, step time: 1.0312
# 15/295, train_loss: 0.9281, step time: 1.0345
# 16/295, train_loss: 0.9536, step time: 1.0511
# 17/295, train_loss: 0.9403, step time: 1.0559
# 18/295, train_loss: 0.9676, step time: 1.0340
# 19/295, train_loss: 0.9328, step time: 1.0286
# 20/295, train_loss: 0.9387, step time: 1.0285
# 21/295, train_loss: 0.9965, step time: 1.0328
# 22/295, train_loss: 0.9204, step time: 1.0367
# 23/295, train_loss: 0.9880, step time: 1.0516
# 24/295, train_loss: 0.9967, step time: 1.0288
# 25/295, train_loss: 0.9634, step time: 1.0306
# 26/295, train_loss: 0.9923, step time: 1.0309
# 27/295, train_loss: 0.9577, step time: 1.0671
# 28/295, train_loss: 0.9215, step time: 1.0509
# 29/295, train_loss: 0.9845, step time: 1.0338
# 30/295, train_loss: 0.9175, step time: 1.0340
# 31/295, train_loss: 0.9847, step time: 1.0383
# 32/295, train_loss: 0.9921, step time: 1.0345
# 33/295, train_loss: 0.9913, step time: 1.0564
# 34/295, train_loss: 0.9474, step time: 1.0469
# 35/295, train_loss: 0.9281, step time: 1.0319
# 36/295, train_loss: 0.9452, step time: 1.0305
# 37/295, train_loss: 0.9057, step time: 1.0386
# 38/295, train_loss: 0.9560, step time: 1.0387
# 39/295, train_loss: 0.9770, step time: 1.0381
# 40/295, train_loss: 0.9175, step time: 1.0325
# 41/295, train_loss: 0.9416, step time: 1.0343
# 42/295, train_loss: 0.9866, step time: 1.0511
# 43/295, train_loss: 0.9684, step time: 1.0391
# 44/295, train_loss: 0.9871, step time: 1.0312
# 45/295, train_loss: 0.9938, step time: 1.0345
# 46/295, train_loss: 0.9611, step time: 1.0355
# 47/295, train_loss: 0.9166, step time: 1.0362
# 48/295, train_loss: 0.9311, step time: 1.0596
# 49/295, train_loss: 0.9425, step time: 1.0321
# 50/295, train_loss: 0.9132, step time: 1.0298
# 51/295, train_loss: 0.9831, step time: 1.1231
# 52/295, train_loss: 0.9683, step time: 1.0292
# 53/295, train_loss: 0.9569, step time: 1.0349
# 54/295, train_loss: 0.9222, step time: 1.0366
# 55/295, train_loss: 0.9109, step time: 1.0361
# 56/295, train_loss: 0.9708, step time: 1.0473
# 57/295, train_loss: 0.9800, step time: 1.0680
# 58/295, train_loss: 0.9810, step time: 1.0451
# 59/295, train_loss: 0.9526, step time: 1.0552
# 60/295, train_loss: 0.9443, step time: 1.0356
# 61/295, train_loss: 0.9358, step time: 1.0368
# 62/295, train_loss: 0.9347, step time: 1.0348
# 63/295, train_loss: 0.9491, step time: 1.0503
# 64/295, train_loss: 0.8944, step time: 1.0994
# 65/295, train_loss: 0.9502, step time: 1.0324
# 66/295, train_loss: 0.9728, step time: 1.0344
# 67/295, train_loss: 0.9589, step time: 1.0489
# 68/295, train_loss: 0.9713, step time: 1.0410
# 69/295, train_loss: 0.9295, step time: 1.0354
# 70/295, train_loss: 0.8723, step time: 1.0345
# 71/295, train_loss: 0.9380, step time: 1.0597
# 72/295, train_loss: 0.9584, step time: 1.0539
# 73/295, train_loss: 0.9495, step time: 1.0562
# 74/295, train_loss: 0.9219, step time: 1.0344
# 75/295, train_loss: 0.9833, step time: 1.0550
# 76/295, train_loss: 0.9549, step time: 1.0522
# 77/295, train_loss: 0.9148, step time: 1.0494
# 78/295, train_loss: 0.9041, step time: 1.0350
# 79/295, train_loss: 0.8953, step time: 1.0321
# 80/295, train_loss: 0.9802, step time: 1.0664
# 81/295, train_loss: 0.9888, step time: 1.0357
# 82/295, train_loss: 0.9756, step time: 1.0437
# 83/295, train_loss: 0.9849, step time: 1.0363
# 84/295, train_loss: 0.9188, step time: 1.1088
# 85/295, train_loss: 0.9680, step time: 1.0583
# 86/295, train_loss: 0.9864, step time: 1.0331
# 87/295, train_loss: 0.9211, step time: 1.0384
# 88/295, train_loss: 0.9733, step time: 1.0331
# 89/295, train_loss: 0.9800, step time: 1.0806
# 90/295, train_loss: 0.8944, step time: 1.0528
# 91/295, train_loss: 0.9692, step time: 1.0371
# 92/295, train_loss: 0.9739, step time: 1.0295
# 93/295, train_loss: 0.9403, step time: 1.0285
# 94/295, train_loss: 0.9129, step time: 1.0299
# 95/295, train_loss: 0.9758, step time: 1.0361
# 96/295, train_loss: 0.9439, step time: 1.0396
# 97/295, train_loss: 0.9446, step time: 1.0329
# 98/295, train_loss: 0.9494, step time: 1.0684
# 99/295, train_loss: 0.9507, step time: 1.0655
# 100/295, train_loss: 0.9138, step time: 1.0299
# 101/295, train_loss: 0.9547, step time: 1.0308
# 102/295, train_loss: 0.9242, step time: 1.0292
# 103/295, train_loss: 0.9682, step time: 1.1046
# 104/295, train_loss: 0.9142, step time: 1.0479
# 105/295, train_loss: 0.9396, step time: 1.0454
# 106/295, train_loss: 0.9718, step time: 1.0360
# 107/295, train_loss: 0.9173, step time: 1.0657
# 108/295, train_loss: 0.9782, step time: 1.0313
# 109/295, train_loss: 0.8780, step time: 1.0317
# 110/295, train_loss: 0.9623, step time: 1.0604
# 111/295, train_loss: 0.8839, step time: 1.0889
# 112/295, train_loss: 0.9692, step time: 1.0297
# 113/295, train_loss: 0.9161, step time: 1.0457
# 114/295, train_loss: 0.9512, step time: 1.0549
# 115/295, train_loss: 0.9710, step time: 1.0322
# 116/295, train_loss: 0.9044, step time: 1.0376
# 117/295, train_loss: 0.9402, step time: 1.0350
# 118/295, train_loss: 0.9179, step time: 1.0365
# 119/295, train_loss: 0.9859, step time: 1.0857
# 120/295, train_loss: 0.9265, step time: 1.0349
# 121/295, train_loss: 0.8826, step time: 1.0304
# 122/295, train_loss: 0.8818, step time: 1.0360
# 123/295, train_loss: 0.9298, step time: 1.0285
# 124/295, train_loss: 0.9783, step time: 1.0533
# 125/295, train_loss: 0.9489, step time: 1.0401
# 126/295, train_loss: 0.9729, step time: 1.0289
# 127/295, train_loss: 0.9834, step time: 1.0556
# 128/295, train_loss: 0.9672, step time: 1.0380
# 129/295, train_loss: 0.9263, step time: 1.0353
# 130/295, train_loss: 0.9162, step time: 1.0359
# 131/295, train_loss: 0.9471, step time: 1.0317
# 132/295, train_loss: 0.9477, step time: 1.0326
# 133/295, train_loss: 0.8919, step time: 1.0359
# 134/295, train_loss: 0.9319, step time: 1.0348
# 135/295, train_loss: 0.9683, step time: 1.0306
# 136/295, train_loss: 0.8871, step time: 1.0698
# 137/295, train_loss: 0.9379, step time: 1.0359
# 138/295, train_loss: 0.9888, step time: 1.0381
# 139/295, train_loss: 0.9287, step time: 1.0926
# 140/295, train_loss: 0.9502, step time: 1.0532
# 141/295, train_loss: 0.9362, step time: 1.1225
# 142/295, train_loss: 0.9219, step time: 1.0312
# 143/295, train_loss: 0.9038, step time: 1.0399
# 144/295, train_loss: 0.9843, step time: 1.0364
# 145/295, train_loss: 0.9232, step time: 1.0877
# 146/295, train_loss: 0.9148, step time: 1.0351
# 147/295, train_loss: 0.9702, step time: 1.0347
# 148/295, train_loss: 0.9734, step time: 1.0477
# 149/295, train_loss: 0.9345, step time: 1.0367
# 150/295, train_loss: 0.9077, step time: 1.0313
# 151/295, train_loss: 0.9573, step time: 1.0320
# 152/295, train_loss: 0.9853, step time: 1.0712
# 153/295, train_loss: 0.9727, step time: 1.0777
# 154/295, train_loss: 0.9543, step time: 1.0355
# 155/295, train_loss: 0.8835, step time: 1.0366
# 156/295, train_loss: 0.9286, step time: 1.0486
# 157/295, train_loss: 0.9342, step time: 1.0398
# 158/295, train_loss: 0.8822, step time: 1.0309
# 159/295, train_loss: 0.9499, step time: 1.0325
# 160/295, train_loss: 0.8987, step time: 1.0580
# 161/295, train_loss: 0.9371, step time: 1.0382
# 162/295, train_loss: 0.9343, step time: 1.0297
# 163/295, train_loss: 0.9822, step time: 1.0313
# 164/295, train_loss: 0.9672, step time: 1.0338
# 165/295, train_loss: 0.9534, step time: 1.0419
# 166/295, train_loss: 0.9411, step time: 1.0347
# 167/295, train_loss: 0.8623, step time: 1.0364
# 168/295, train_loss: 0.9308, step time: 1.0376
# 169/295, train_loss: 0.9437, step time: 1.0341
# 170/295, train_loss: 0.9224, step time: 1.0362
# 171/295, train_loss: 0.9311, step time: 1.0397
# 172/295, train_loss: 0.9698, step time: 1.0310
# 173/295, train_loss: 0.9647, step time: 1.0314
# 174/295, train_loss: 0.9411, step time: 1.0314
# 175/295, train_loss: 0.9488, step time: 1.0319
# 176/295, train_loss: 0.8901, step time: 1.0345
# 177/295, train_loss: 0.8970, step time: 1.0591
# 178/295, train_loss: 0.9870, step time: 1.0365
# 179/295, train_loss: 0.9570, step time: 1.0304
# 180/295, train_loss: 0.9589, step time: 1.0316
# 181/295, train_loss: 0.9804, step time: 1.0351
# 182/295, train_loss: 0.9043, step time: 1.0615
# 183/295, train_loss: 0.9823, step time: 1.1013
# 184/295, train_loss: 0.9404, step time: 1.0600
# 185/295, train_loss: 0.9869, step time: 1.0310
# 186/295, train_loss: 0.9185, step time: 1.0307
# 187/295, train_loss: 0.9761, step time: 1.0303
# 188/295, train_loss: 0.8934, step time: 1.0378
# 189/295, train_loss: 0.9616, step time: 1.0309
# 190/295, train_loss: 0.9871, step time: 1.0338
# 191/295, train_loss: 0.9200, step time: 1.0446
# 192/295, train_loss: 0.9288, step time: 1.0319
# 193/295, train_loss: 0.9242, step time: 1.0372
# 194/295, train_loss: 0.8805, step time: 1.0409
# 195/295, train_loss: 0.8681, step time: 1.0517
# 196/295, train_loss: 0.9292, step time: 1.0316
# 197/295, train_loss: 0.8589, step time: 1.0310
# 198/295, train_loss: 0.9436, step time: 1.0406
# 199/295, train_loss: 0.8575, step time: 1.0490
# 200/295, train_loss: 0.9119, step time: 1.0317
# 201/295, train_loss: 0.9032, step time: 1.0312
# 202/295, train_loss: 0.9236, step time: 1.0326
# 203/295, train_loss: 0.9634, step time: 1.0308
# 204/295, train_loss: 0.9818, step time: 1.0311
# 205/295, train_loss: 0.9429, step time: 1.0321
# 206/295, train_loss: 0.9920, step time: 1.0343
# 207/295, train_loss: 0.8792, step time: 1.0331
# 208/295, train_loss: 0.9481, step time: 1.0341
# 209/295, train_loss: 0.9766, step time: 1.0397
# 210/295, train_loss: 0.8815, step time: 1.0298
# 211/295, train_loss: 0.8416, step time: 1.0340
# 212/295, train_loss: 0.9395, step time: 1.0377
# 213/295, train_loss: 0.9740, step time: 1.0344
# 214/295, train_loss: 0.8351, step time: 1.0399
# 215/295, train_loss: 0.9570, step time: 1.0312
# 216/295, train_loss: 0.9215, step time: 1.0383
# 217/295, train_loss: 0.9452, step time: 1.0315
# 218/295, train_loss: 0.9880, step time: 1.0379
# 219/295, train_loss: 0.8597, step time: 1.0376
# 220/295, train_loss: 0.9069, step time: 1.0318
# 221/295, train_loss: 0.9392, step time: 1.0362
# 222/295, train_loss: 0.9490, step time: 1.0355
# 223/295, train_loss: 0.9800, step time: 1.0494
# 224/295, train_loss: 0.9833, step time: 1.0317
# 225/295, train_loss: 0.9882, step time: 1.0519
# 226/295, train_loss: 0.9620, step time: 1.0317
# 227/295, train_loss: 0.9236, step time: 1.0627
# 228/295, train_loss: 0.9665, step time: 1.0400
# 229/295, train_loss: 0.9539, step time: 1.0338
# 230/295, train_loss: 0.9514, step time: 1.0386
# 231/295, train_loss: 0.9054, step time: 1.0306
# 232/295, train_loss: 0.9005, step time: 1.0333
# 233/295, train_loss: 0.9401, step time: 1.0363
# 234/295, train_loss: 0.9242, step time: 1.0417
# 235/295, train_loss: 0.9689, step time: 1.0405
# 236/295, train_loss: 0.9277, step time: 1.0380
# 237/295, train_loss: 0.8805, step time: 1.0328
# 238/295, train_loss: 0.9596, step time: 1.0520
# 239/295, train_loss: 0.9164, step time: 1.0566
# 240/295, train_loss: 0.9300, step time: 1.0367
# 241/295, train_loss: 0.9073, step time: 1.0364
# 242/295, train_loss: 0.8561, step time: 1.0345
# 243/295, train_loss: 0.9208, step time: 1.0352
# 244/295, train_loss: 0.9252, step time: 1.0379
# 245/295, train_loss: 0.8924, step time: 1.0317
# 246/295, train_loss: 0.9121, step time: 1.0375
# 247/295, train_loss: 0.9329, step time: 1.0446
# 248/295, train_loss: 0.9394, step time: 1.0311
# 249/295, train_loss: 0.9024, step time: 1.0309
# 250/295, train_loss: 0.8670, step time: 1.0342
# 251/295, train_loss: 0.9040, step time: 1.0342
# 252/295, train_loss: 0.8802, step time: 1.0371
# 253/295, train_loss: 0.9703, step time: 1.0414
# 254/295, train_loss: 0.8524, step time: 1.0654
# 255/295, train_loss: 0.9492, step time: 1.0339
# 256/295, train_loss: 0.8975, step time: 1.0376
# 257/295, train_loss: 0.9815, step time: 1.0358
# 258/295, train_loss: 0.8831, step time: 1.0363
# 259/295, train_loss: 0.9089, step time: 1.0346
# 260/295, train_loss: 0.8835, step time: 1.0369
# 261/295, train_loss: 0.9513, step time: 1.0332
# 262/295, train_loss: 0.9002, step time: 1.0355
# 263/295, train_loss: 0.9643, step time: 1.0582
# 264/295, train_loss: 0.9157, step time: 1.0546
# 265/295, train_loss: 0.9707, step time: 1.0351
# 266/295, train_loss: 0.8982, step time: 1.0384
# 267/295, train_loss: 0.8646, step time: 1.0428
# 268/295, train_loss: 0.9589, step time: 1.0454
# 269/295, train_loss: 0.9305, step time: 1.0337
# 270/295, train_loss: 0.8675, step time: 1.0449
# 271/295, train_loss: 0.8620, step time: 1.0336
# 272/295, train_loss: 0.9707, step time: 1.0308
# 273/295, train_loss: 0.8347, step time: 1.0332
# 274/295, train_loss: 0.9031, step time: 1.0624
# 275/295, train_loss: 0.9185, step time: 1.0349
# 276/295, train_loss: 0.9833, step time: 1.0298
# 277/295, train_loss: 0.8688, step time: 1.0350
# 278/295, train_loss: 0.9749, step time: 1.0324
# 279/295, train_loss: 0.9509, step time: 1.0348
# 280/295, train_loss: 0.8410, step time: 1.0361
# 281/295, train_loss: 0.8860, step time: 1.0378
# 282/295, train_loss: 0.7852, step time: 1.0580
# 283/295, train_loss: 0.9517, step time: 1.0330
# 284/295, train_loss: 0.9810, step time: 1.0639
# 285/295, train_loss: 0.9015, step time: 1.0339
# 286/295, train_loss: 0.9349, step time: 1.0338
# 287/295, train_loss: 0.9049, step time: 1.0355
# 288/295, train_loss: 0.9340, step time: 1.0301
# 289/295, train_loss: 0.9759, step time: 1.0278
# 290/295, train_loss: 0.9697, step time: 1.0282
# 291/295, train_loss: 0.8880, step time: 1.0278
# 292/295, train_loss: 0.8774, step time: 1.0285
# 293/295, train_loss: 0.9414, step time: 1.0281
# 294/295, train_loss: 0.8599, step time: 1.0276
# 295/295, train_loss: 0.9776, step time: 1.0269
# epoch 2 average loss: 0.9366
# saved new best metric model
# current epoch: 2 current mean dice: 0.3552 tc: 0.2496 wt: 0.6239 et: 0.1726
# best mean dice: 0.3552 at epoch: 2
# time consuming of epoch 2 is: 376.2466
# ----------
# epoch 3/100
# 1/295, train_loss: 0.9082, step time: 1.0905
# 2/295, train_loss: 0.9311, step time: 1.0530
# 3/295, train_loss: 0.8418, step time: 1.0883
# 4/295, train_loss: 0.9451, step time: 1.0818
# 5/295, train_loss: 0.9643, step time: 1.0330
# 6/295, train_loss: 0.9749, step time: 1.0734
# 7/295, train_loss: 0.9296, step time: 1.0932
# 8/295, train_loss: 0.9476, step time: 1.0547
# 9/295, train_loss: 0.8915, step time: 1.0630
# 10/295, train_loss: 0.9273, step time: 1.0506
# 11/295, train_loss: 0.9071, step time: 1.0583
# 12/295, train_loss: 0.8728, step time: 1.0826
# 13/295, train_loss: 0.9411, step time: 1.0339
# 14/295, train_loss: 0.9115, step time: 1.0302
# 15/295, train_loss: 0.9496, step time: 1.0457
# 16/295, train_loss: 0.9447, step time: 1.0411
# 17/295, train_loss: 0.9204, step time: 1.0327
# 18/295, train_loss: 0.9050, step time: 1.0294
# 19/295, train_loss: 0.9063, step time: 1.0289
# 20/295, train_loss: 0.9487, step time: 1.0361
# 21/295, train_loss: 0.8952, step time: 1.0719
# 22/295, train_loss: 0.9650, step time: 1.1068
# 23/295, train_loss: 0.8728, step time: 1.0455
# 24/295, train_loss: 0.8538, step time: 1.0342
# 25/295, train_loss: 0.9457, step time: 1.0387
# 26/295, train_loss: 0.8929, step time: 1.0335
# 27/295, train_loss: 0.8841, step time: 1.0315
# 28/295, train_loss: 0.8795, step time: 1.0334
# 29/295, train_loss: 0.9439, step time: 1.0373
# 30/295, train_loss: 0.9199, step time: 1.0597
# 31/295, train_loss: 0.8966, step time: 1.0459
# 32/295, train_loss: 0.9734, step time: 1.0934
# 33/295, train_loss: 0.9069, step time: 1.0304
# 34/295, train_loss: 0.9186, step time: 1.0350
# 35/295, train_loss: 0.9583, step time: 1.0393
# 36/295, train_loss: 0.8488, step time: 1.0560
# 37/295, train_loss: 0.8955, step time: 1.0416
# 38/295, train_loss: 0.9070, step time: 1.0293
# 39/295, train_loss: 0.9752, step time: 1.0326
# 40/295, train_loss: 0.8941, step time: 1.0331
# 41/295, train_loss: 0.8726, step time: 1.0364
# 42/295, train_loss: 0.8438, step time: 1.0367
# 43/295, train_loss: 0.9750, step time: 1.0645
# 44/295, train_loss: 0.8894, step time: 1.0508
# 45/295, train_loss: 0.8408, step time: 1.0323
# 46/295, train_loss: 0.8160, step time: 1.1320
# 47/295, train_loss: 0.9623, step time: 1.0336
# 48/295, train_loss: 0.9585, step time: 1.0515
# 49/295, train_loss: 0.8500, step time: 1.0322
# 50/295, train_loss: 0.8965, step time: 1.0580
# 51/295, train_loss: 0.9018, step time: 1.0543
# 52/295, train_loss: 0.8237, step time: 1.0335
# 53/295, train_loss: 0.9209, step time: 1.0469
# 54/295, train_loss: 0.8054, step time: 1.0530
# 55/295, train_loss: 0.9138, step time: 1.0325
# 56/295, train_loss: 0.9204, step time: 1.0784
# 57/295, train_loss: 0.9819, step time: 1.0306
# 58/295, train_loss: 0.8539, step time: 1.0407
# 59/295, train_loss: 0.9081, step time: 1.0400
# 60/295, train_loss: 0.9081, step time: 1.0405
# 61/295, train_loss: 0.9193, step time: 1.0368
# 62/295, train_loss: 0.9366, step time: 1.0435
# 63/295, train_loss: 0.9012, step time: 1.0420
# 64/295, train_loss: 0.8978, step time: 1.0581
# 65/295, train_loss: 0.8721, step time: 1.0483
# 66/295, train_loss: 0.9307, step time: 1.0341
# 67/295, train_loss: 0.8919, step time: 1.0629
# 68/295, train_loss: 0.9564, step time: 1.0652
# 69/295, train_loss: 0.8322, step time: 1.0492
# 70/295, train_loss: 0.8526, step time: 1.0416
# 71/295, train_loss: 0.9165, step time: 1.0309
# 72/295, train_loss: 0.8714, step time: 1.0285
# 73/295, train_loss: 0.9279, step time: 1.0420
# 74/295, train_loss: 0.8841, step time: 1.0305
# 75/295, train_loss: 0.8656, step time: 1.0288
# 76/295, train_loss: 0.9751, step time: 1.0356
# 77/295, train_loss: 0.8665, step time: 1.0489
# 78/295, train_loss: 0.9695, step time: 1.0352
# 79/295, train_loss: 0.9582, step time: 1.0305
# 80/295, train_loss: 0.9134, step time: 1.0438
# 81/295, train_loss: 0.8379, step time: 1.0369
# 82/295, train_loss: 0.8614, step time: 1.0302
# 83/295, train_loss: 0.9060, step time: 1.0336
# 84/295, train_loss: 0.8515, step time: 1.0379
# 85/295, train_loss: 0.8422, step time: 1.0397
# 86/295, train_loss: 0.8533, step time: 1.0762
# 87/295, train_loss: 0.9381, step time: 1.0298
# 88/295, train_loss: 0.9159, step time: 1.0728
# 89/295, train_loss: 0.8530, step time: 1.0367
# 90/295, train_loss: 0.7744, step time: 1.0295
# 91/295, train_loss: 0.9920, step time: 1.0402
# 92/295, train_loss: 0.8688, step time: 1.0694
# 93/295, train_loss: 0.8749, step time: 1.0286
# 94/295, train_loss: 0.8260, step time: 1.0303
# 95/295, train_loss: 0.8645, step time: 1.0512
# 96/295, train_loss: 0.8512, step time: 1.0486
# 97/295, train_loss: 0.9867, step time: 1.0377
# 98/295, train_loss: 0.8290, step time: 1.0441
# 99/295, train_loss: 0.8661, step time: 1.0418
# 100/295, train_loss: 0.8979, step time: 1.0834
# 101/295, train_loss: 0.8755, step time: 1.0328
# 102/295, train_loss: 0.9602, step time: 1.0342
# 103/295, train_loss: 0.8754, step time: 1.0600
# 104/295, train_loss: 0.8191, step time: 1.0350
# 105/295, train_loss: 0.8820, step time: 1.0330
# 106/295, train_loss: 0.9706, step time: 1.0337
# 107/295, train_loss: 0.8146, step time: 1.0956
# 108/295, train_loss: 0.9731, step time: 1.0347
# 109/295, train_loss: 0.9155, step time: 1.0601
# 110/295, train_loss: 0.7761, step time: 1.0475
# 111/295, train_loss: 0.9800, step time: 1.0388
# 112/295, train_loss: 0.8637, step time: 1.0498
# 113/295, train_loss: 0.9331, step time: 1.0305
# 114/295, train_loss: 0.8558, step time: 1.0440
# 115/295, train_loss: 0.9440, step time: 1.0434
# 116/295, train_loss: 0.7955, step time: 1.0622
# 117/295, train_loss: 0.7847, step time: 1.0417
# 118/295, train_loss: 0.9597, step time: 1.0379
# 119/295, train_loss: 0.7395, step time: 1.0621
# 120/295, train_loss: 0.9317, step time: 1.0517
# 121/295, train_loss: 0.8747, step time: 1.0435
# 122/295, train_loss: 0.9701, step time: 1.0575
# 123/295, train_loss: 0.8887, step time: 1.0376
# 124/295, train_loss: 0.8704, step time: 1.0419
# 125/295, train_loss: 0.9702, step time: 1.0291
# 126/295, train_loss: 0.9044, step time: 1.0328
# 127/295, train_loss: 0.9855, step time: 1.0310
# 128/295, train_loss: 0.9501, step time: 1.0352
# 129/295, train_loss: 0.9287, step time: 1.0339
# 130/295, train_loss: 0.9211, step time: 1.0625
# 131/295, train_loss: 0.8236, step time: 1.0361
# 132/295, train_loss: 0.8455, step time: 1.1010
# 133/295, train_loss: 0.8888, step time: 1.0315
# 134/295, train_loss: 0.9278, step time: 1.0344
# 135/295, train_loss: 0.9567, step time: 1.0528
# 136/295, train_loss: 0.7900, step time: 1.0363
# 137/295, train_loss: 0.7507, step time: 1.0542
# 138/295, train_loss: 0.9011, step time: 1.0424
# 139/295, train_loss: 0.8096, step time: 1.0485
# 140/295, train_loss: 0.9545, step time: 1.0374
# 141/295, train_loss: 0.8117, step time: 1.1005
# 142/295, train_loss: 0.9772, step time: 1.0352
# 143/295, train_loss: 0.8103, step time: 1.0328
# 144/295, train_loss: 0.8973, step time: 1.0292
# 145/295, train_loss: 0.9339, step time: 1.0379
# 146/295, train_loss: 0.8805, step time: 1.0373
# 147/295, train_loss: 0.9147, step time: 1.0371
# 148/295, train_loss: 0.9802, step time: 1.0426
# 149/295, train_loss: 0.8847, step time: 1.0351
# 150/295, train_loss: 0.8160, step time: 1.0322
# 151/295, train_loss: 0.9556, step time: 1.0499
# 152/295, train_loss: 0.9428, step time: 1.1132
# 153/295, train_loss: 0.8867, step time: 1.0427
# 154/295, train_loss: 0.7653, step time: 1.0623
# 155/295, train_loss: 0.7957, step time: 1.0312
# 156/295, train_loss: 0.8363, step time: 1.0345
# 157/295, train_loss: 0.9449, step time: 1.0314
# 158/295, train_loss: 0.9726, step time: 1.0330
# 159/295, train_loss: 0.9301, step time: 1.0466
# 160/295, train_loss: 0.9726, step time: 1.0344
# 161/295, train_loss: 0.8701, step time: 1.0652
# 162/295, train_loss: 0.9272, step time: 1.0690
# 163/295, train_loss: 0.7908, step time: 1.0411
# 164/295, train_loss: 0.8257, step time: 1.0438
# 165/295, train_loss: 0.8101, step time: 1.0388
# 166/295, train_loss: 0.8975, step time: 1.0289
# 167/295, train_loss: 0.8610, step time: 1.0410
# 168/295, train_loss: 0.8215, step time: 1.1041
# 169/295, train_loss: 0.9370, step time: 1.0316
# 170/295, train_loss: 0.8550, step time: 1.0428
# 171/295, train_loss: 0.8515, step time: 1.0321
# 172/295, train_loss: 0.8787, step time: 1.0356
# 173/295, train_loss: 0.9197, step time: 1.0362
# 174/295, train_loss: 0.9467, step time: 1.0355
# 175/295, train_loss: 0.9748, step time: 1.0464
# 176/295, train_loss: 0.9039, step time: 1.0726
# 177/295, train_loss: 0.8827, step time: 1.0439
# 178/295, train_loss: 0.8576, step time: 1.0423
# 179/295, train_loss: 0.8230, step time: 1.0553
# 180/295, train_loss: 0.9271, step time: 1.0354
# 181/295, train_loss: 0.8771, step time: 1.0480
# 182/295, train_loss: 0.8359, step time: 1.0447
# 183/295, train_loss: 0.9565, step time: 1.0391
# 184/295, train_loss: 0.7593, step time: 1.0628
# 185/295, train_loss: 0.9889, step time: 1.0418
# 186/295, train_loss: 0.8817, step time: 1.0558
# 187/295, train_loss: 0.7741, step time: 1.0322
# 188/295, train_loss: 0.7693, step time: 1.0441
# 189/295, train_loss: 0.9450, step time: 1.0317
# 190/295, train_loss: 0.9259, step time: 1.0353
# 191/295, train_loss: 0.9264, step time: 1.0556
# 192/295, train_loss: 0.8970, step time: 1.0523
# 193/295, train_loss: 0.7474, step time: 1.0735
# 194/295, train_loss: 0.8615, step time: 1.0344
# 195/295, train_loss: 0.8560, step time: 1.0400
# 196/295, train_loss: 0.7739, step time: 1.0517
# 197/295, train_loss: 0.8324, step time: 1.0334
# 198/295, train_loss: 0.9520, step time: 1.0380
# 199/295, train_loss: 0.8495, step time: 1.0373
# 200/295, train_loss: 0.8937, step time: 1.0491
# 201/295, train_loss: 0.8059, step time: 1.1189
# 202/295, train_loss: 0.9558, step time: 1.0418
# 203/295, train_loss: 0.8594, step time: 1.0327
# 204/295, train_loss: 0.7732, step time: 1.0344
# 205/295, train_loss: 0.8402, step time: 1.0370
# 206/295, train_loss: 0.9013, step time: 1.0362
# 207/295, train_loss: 0.8027, step time: 1.0345
# 208/295, train_loss: 0.9556, step time: 1.0315
# 209/295, train_loss: 0.8722, step time: 1.0328
# 210/295, train_loss: 0.9154, step time: 1.0435
# 211/295, train_loss: 0.9136, step time: 1.0391
# 212/295, train_loss: 0.8261, step time: 1.0646
# 213/295, train_loss: 0.8757, step time: 1.0375
# 214/295, train_loss: 0.8607, step time: 1.0351
# 215/295, train_loss: 0.9431, step time: 1.0323
# 216/295, train_loss: 0.8557, step time: 1.0406
# 217/295, train_loss: 0.7661, step time: 1.0344
# 218/295, train_loss: 0.8650, step time: 1.0311
# 219/295, train_loss: 0.7880, step time: 1.1078
# 220/295, train_loss: 0.7747, step time: 1.1006
# 221/295, train_loss: 0.7534, step time: 1.0391
# 222/295, train_loss: 0.7953, step time: 1.0330
# 223/295, train_loss: 0.9164, step time: 1.0306
# 224/295, train_loss: 0.9679, step time: 1.0379
# 225/295, train_loss: 0.7983, step time: 1.0754
# 226/295, train_loss: 0.7355, step time: 1.0358
# 227/295, train_loss: 0.7950, step time: 1.0775
# 228/295, train_loss: 0.9729, step time: 1.0504
# 229/295, train_loss: 0.9598, step time: 1.0552
# 230/295, train_loss: 0.9030, step time: 1.0557
# 231/295, train_loss: 0.9296, step time: 1.0354
# 232/295, train_loss: 0.9155, step time: 1.0320
# 233/295, train_loss: 0.8591, step time: 1.0364
# 234/295, train_loss: 0.8012, step time: 1.0462
# 235/295, train_loss: 0.8883, step time: 1.0417
# 236/295, train_loss: 0.9425, step time: 1.0323
# 237/295, train_loss: 0.7517, step time: 1.0594
# 238/295, train_loss: 0.7394, step time: 1.1033
# 239/295, train_loss: 0.8862, step time: 1.0452
# 240/295, train_loss: 0.9480, step time: 1.0544
# 241/295, train_loss: 0.7891, step time: 1.0545
# 242/295, train_loss: 0.7721, step time: 1.0404
# 243/295, train_loss: 0.9222, step time: 1.0356
# 244/295, train_loss: 0.7903, step time: 1.0348
# 245/295, train_loss: 0.8742, step time: 1.0348
# 246/295, train_loss: 0.8101, step time: 1.0386
# 247/295, train_loss: 0.8005, step time: 1.0539
# 248/295, train_loss: 0.8038, step time: 1.0561
# 249/295, train_loss: 0.8491, step time: 1.0316
# 250/295, train_loss: 0.7815, step time: 1.0311
# 251/295, train_loss: 0.9385, step time: 1.0613
# 252/295, train_loss: 0.7166, step time: 1.0341
# 253/295, train_loss: 0.8020, step time: 1.0527
# 254/295, train_loss: 0.8054, step time: 1.0333
# 255/295, train_loss: 0.8002, step time: 1.0351
# 256/295, train_loss: 0.8034, step time: 1.0453
# 257/295, train_loss: 0.8358, step time: 1.0943
# 258/295, train_loss: 0.8063, step time: 1.0846
# 259/295, train_loss: 0.8506, step time: 1.0536
# 260/295, train_loss: 0.8457, step time: 1.0333
# 261/295, train_loss: 0.8383, step time: 1.0376
# 262/295, train_loss: 0.7375, step time: 1.0306
# 263/295, train_loss: 0.8795, step time: 1.0365
# 264/295, train_loss: 0.7890, step time: 1.0380
# 265/295, train_loss: 0.8802, step time: 1.0317
# 266/295, train_loss: 0.8330, step time: 1.0348
# 267/295, train_loss: 0.8877, step time: 1.0569
# 268/295, train_loss: 0.8748, step time: 1.0356
# 269/295, train_loss: 0.8469, step time: 1.0299
# 270/295, train_loss: 0.9541, step time: 1.0351
# 271/295, train_loss: 0.7747, step time: 1.0558
# 272/295, train_loss: 0.7359, step time: 1.1163
# 273/295, train_loss: 0.7645, step time: 1.0364
# 274/295, train_loss: 0.8313, step time: 1.0405
# 275/295, train_loss: 0.7671, step time: 1.0382
# 276/295, train_loss: 0.9614, step time: 1.0327
# 277/295, train_loss: 0.9236, step time: 1.0327
# 278/295, train_loss: 0.7460, step time: 1.0325
# 279/295, train_loss: 0.9192, step time: 1.0395
# 280/295, train_loss: 0.7894, step time: 1.0321
# 281/295, train_loss: 0.7811, step time: 1.0519
# 282/295, train_loss: 0.7225, step time: 1.0530
# 283/295, train_loss: 0.8936, step time: 1.0334
# 284/295, train_loss: 0.9337, step time: 1.0329
# 285/295, train_loss: 0.8179, step time: 1.0348
# 286/295, train_loss: 0.9532, step time: 1.0374
# 287/295, train_loss: 0.9663, step time: 1.0391
# 288/295, train_loss: 0.7974, step time: 1.0298
# 289/295, train_loss: 0.8070, step time: 1.0277
# 290/295, train_loss: 0.7518, step time: 1.0327
# 291/295, train_loss: 0.8404, step time: 1.0327
# 292/295, train_loss: 0.7691, step time: 1.0281
# 293/295, train_loss: 0.8740, step time: 1.0277
# 294/295, train_loss: 0.9122, step time: 1.0278
# 295/295, train_loss: 0.7558, step time: 1.0271
# epoch 3 average loss: 0.8767
# saved new best metric model
# current epoch: 3 current mean dice: 0.5156 tc: 0.3846 wt: 0.7983 et: 0.3377
# best mean dice: 0.5156 at epoch: 3
# time consuming of epoch 3 is: 374.1107
# ----------
# epoch 4/100
# 1/295, train_loss: 0.8200, step time: 1.0540
# 2/295, train_loss: 0.7290, step time: 1.0787
# 3/295, train_loss: 0.9592, step time: 1.0479
# 4/295, train_loss: 0.8956, step time: 1.0568
# 5/295, train_loss: 0.8149, step time: 1.0507
# 6/295, train_loss: 0.8273, step time: 1.0374
# 7/295, train_loss: 0.8141, step time: 1.0363
# 8/295, train_loss: 0.7339, step time: 1.0351
# 9/295, train_loss: 0.6515, step time: 1.0359
# 10/295, train_loss: 0.9357, step time: 1.0301
# 11/295, train_loss: 0.6887, step time: 1.0996
# 12/295, train_loss: 0.7328, step time: 1.0364
# 13/295, train_loss: 0.8196, step time: 1.0318
# 14/295, train_loss: 0.7374, step time: 1.0467
# 15/295, train_loss: 0.7049, step time: 1.0484
# 16/295, train_loss: 0.8460, step time: 1.0368
# 17/295, train_loss: 0.8155, step time: 1.0277
# 18/295, train_loss: 0.8830, step time: 1.0309
# 19/295, train_loss: 0.7757, step time: 1.0344
# 20/295, train_loss: 0.8013, step time: 1.0301
# 21/295, train_loss: 0.6879, step time: 1.0365
# 22/295, train_loss: 0.8104, step time: 1.0540
# 23/295, train_loss: 0.7203, step time: 1.0330
# 24/295, train_loss: 0.9150, step time: 1.0576
# 25/295, train_loss: 0.6585, step time: 1.0330
# 26/295, train_loss: 0.8904, step time: 1.0324
# 27/295, train_loss: 0.8263, step time: 1.1139
# 28/295, train_loss: 0.7752, step time: 1.0552
# 29/295, train_loss: 0.7684, step time: 1.0515
# 30/295, train_loss: 0.8040, step time: 1.0305
# 31/295, train_loss: 0.9334, step time: 1.0315
# 32/295, train_loss: 0.7819, step time: 1.0306
# 33/295, train_loss: 0.7649, step time: 1.0369
# 34/295, train_loss: 0.8158, step time: 1.0348
# 35/295, train_loss: 0.7842, step time: 1.0386
# 36/295, train_loss: 0.8940, step time: 1.0500
# 37/295, train_loss: 0.7673, step time: 1.0291
# 38/295, train_loss: 0.8180, step time: 1.0536
# 39/295, train_loss: 0.9252, step time: 1.0680
# 40/295, train_loss: 0.8228, step time: 1.0345
# 41/295, train_loss: 0.9157, step time: 1.0357
# 42/295, train_loss: 0.7645, step time: 1.1099
# 43/295, train_loss: 0.7859, step time: 1.0385
# 44/295, train_loss: 0.8212, step time: 1.0677
# 45/295, train_loss: 0.8660, step time: 1.0654
# 46/295, train_loss: 0.8416, step time: 1.0316
# 47/295, train_loss: 0.7886, step time: 1.0507
# 48/295, train_loss: 0.8601, step time: 1.0459
# 49/295, train_loss: 0.7503, step time: 1.0353
# 50/295, train_loss: 0.8722, step time: 1.0384
# 51/295, train_loss: 0.7718, step time: 1.0306
# 52/295, train_loss: 0.8927, step time: 1.0289
# 53/295, train_loss: 0.8722, step time: 1.0281
# 54/295, train_loss: 0.6932, step time: 1.0342
# 55/295, train_loss: 0.6551, step time: 1.0314
# 56/295, train_loss: 0.7411, step time: 1.0369
# 57/295, train_loss: 0.8908, step time: 1.0460
# 58/295, train_loss: 0.8464, step time: 1.0324
# 59/295, train_loss: 0.8034, step time: 1.0634
# 60/295, train_loss: 0.8362, step time: 1.0304
# 61/295, train_loss: 0.6749, step time: 1.0636
# 62/295, train_loss: 0.7891, step time: 1.0324
# 63/295, train_loss: 0.8094, step time: 1.0290
# 64/295, train_loss: 0.7731, step time: 1.0419
# 65/295, train_loss: 0.7426, step time: 1.0509
# 66/295, train_loss: 0.7511, step time: 1.0492
# 67/295, train_loss: 0.7739, step time: 1.0298
# 68/295, train_loss: 0.7384, step time: 1.0631
# 69/295, train_loss: 0.7564, step time: 1.0475
# 70/295, train_loss: 0.6848, step time: 1.0587
# 71/295, train_loss: 0.7403, step time: 1.0314
# 72/295, train_loss: 0.9684, step time: 1.0555
# 73/295, train_loss: 0.9213, step time: 1.0297
# 74/295, train_loss: 0.7131, step time: 1.0314
# 75/295, train_loss: 0.7170, step time: 1.0341
# 76/295, train_loss: 0.8503, step time: 1.0308
# 77/295, train_loss: 0.8522, step time: 1.0671
# 78/295, train_loss: 0.8219, step time: 1.0399
# 79/295, train_loss: 0.8644, step time: 1.0400
# 80/295, train_loss: 0.7911, step time: 1.0431
# 81/295, train_loss: 0.7817, step time: 1.0503
# 82/295, train_loss: 0.8069, step time: 1.0334
# 83/295, train_loss: 0.6890, step time: 1.0347
# 84/295, train_loss: 0.6340, step time: 1.0554
# 85/295, train_loss: 0.8296, step time: 1.0363
# 86/295, train_loss: 0.8777, step time: 1.0513
# 87/295, train_loss: 0.8056, step time: 1.0737
# 88/295, train_loss: 0.8521, step time: 1.0366
# 89/295, train_loss: 0.7539, step time: 1.0359
# 90/295, train_loss: 0.9241, step time: 1.0540
# 91/295, train_loss: 0.9524, step time: 1.0371
# 92/295, train_loss: 0.9434, step time: 1.0735
# 93/295, train_loss: 0.7509, step time: 1.0610
# 94/295, train_loss: 0.7070, step time: 1.0369
# 95/295, train_loss: 0.8554, step time: 1.0392
# 96/295, train_loss: 0.7683, step time: 1.0926
# 97/295, train_loss: 0.7908, step time: 1.0348
# 98/295, train_loss: 0.6546, step time: 1.0434
# 99/295, train_loss: 0.9018, step time: 1.0469
# 100/295, train_loss: 0.6784, step time: 1.0358
# 101/295, train_loss: 0.6884, step time: 1.0609
# 102/295, train_loss: 0.6358, step time: 1.0937
# 103/295, train_loss: 0.7782, step time: 1.0342
# 104/295, train_loss: 0.9031, step time: 1.0377
# 105/295, train_loss: 0.7647, step time: 1.0419
# 106/295, train_loss: 0.6493, step time: 1.0325
# 107/295, train_loss: 0.6805, step time: 1.0342
# 108/295, train_loss: 0.9097, step time: 1.0383
# 109/295, train_loss: 0.6721, step time: 1.0653
# 110/295, train_loss: 0.6523, step time: 1.0391
# 111/295, train_loss: 0.7153, step time: 1.0318
# 112/295, train_loss: 0.9082, step time: 1.0935
# 113/295, train_loss: 0.6888, step time: 1.0321
# 114/295, train_loss: 0.7744, step time: 1.0398
# 115/295, train_loss: 0.7468, step time: 1.0331
# 116/295, train_loss: 0.6589, step time: 1.0700
# 117/295, train_loss: 0.7175, step time: 1.0540
# 118/295, train_loss: 0.8118, step time: 1.0557
# 119/295, train_loss: 0.8522, step time: 1.0335
# 120/295, train_loss: 0.8076, step time: 1.0374
# 121/295, train_loss: 0.8766, step time: 1.0385
# 122/295, train_loss: 0.7428, step time: 1.0370
# 123/295, train_loss: 0.7518, step time: 1.0302
# 124/295, train_loss: 0.8366, step time: 1.0581
# 125/295, train_loss: 0.7470, step time: 1.0372
# 126/295, train_loss: 0.8086, step time: 1.0379
# 127/295, train_loss: 0.7093, step time: 1.0340
# 128/295, train_loss: 0.9321, step time: 1.0286
# 129/295, train_loss: 0.7345, step time: 1.0317
# 130/295, train_loss: 0.8218, step time: 1.0597
# ...
# 258/295, train_loss: 0.1174, step time: 1.0363
# 259/295, train_loss: 0.1594, step time: 1.0385
# 260/295, train_loss: 0.1190, step time: 1.0403
# 261/295, train_loss: 0.0742, step time: 1.0427
# 262/295, train_loss: 0.4043, step time: 1.0350
# 263/295, train_loss: 0.0634, step time: 1.0324
# 264/295, train_loss: 0.1714, step time: 1.0398
# 265/295, train_loss: 0.1217, step time: 1.0491
# 266/295, train_loss: 0.0655, step time: 1.0327
# 267/295, train_loss: 0.0853, step time: 1.0595
# 268/295, train_loss: 0.0632, step time: 1.0346
# 269/295, train_loss: 0.4088, step time: 1.0374
# 270/295, train_loss: 0.2918, step time: 1.0334
# 271/295, train_loss: 0.4177, step time: 1.0344
# 272/295, train_loss: 0.4024, step time: 1.0362
# 273/295, train_loss: 0.1209, step time: 1.0384
# 274/295, train_loss: 0.0485, step time: 1.0333
# 275/295, train_loss: 0.1103, step time: 1.0507
# 276/295, train_loss: 0.0940, step time: 1.0373
# 277/295, train_loss: 0.4170, step time: 1.0356
# 278/295, train_loss: 0.0695, step time: 1.0308
# 279/295, train_loss: 0.0921, step time: 1.0336
# 280/295, train_loss: 0.2096, step time: 1.0345
# 281/295, train_loss: 0.1113, step time: 1.0398
# 282/295, train_loss: 0.1112, step time: 1.0415
# 283/295, train_loss: 0.2321, step time: 1.0420
# 284/295, train_loss: 0.1051, step time: 1.0441
# 285/295, train_loss: 0.2858, step time: 1.0358
# 286/295, train_loss: 0.1035, step time: 1.0400
# 287/295, train_loss: 0.0870, step time: 1.0384
# 288/295, train_loss: 0.0924, step time: 1.0312
# 289/295, train_loss: 0.0884, step time: 1.0289
# 290/295, train_loss: 0.2274, step time: 1.0296
# 291/295, train_loss: 0.0534, step time: 1.0298
# 292/295, train_loss: 0.1048, step time: 1.0298
# 293/295, train_loss: 0.2275, step time: 1.0288
# 294/295, train_loss: 0.1179, step time: 1.0293
# 295/295, train_loss: 0.1014, step time: 1.0285
# epoch 42 average loss: 0.1384
# current epoch: 42 current mean dice: 0.7606 tc: 0.6974 wt: 0.8557 et: 0.7316
# best mean dice: 0.7814 at epoch: 13
# time consuming of epoch 42 is: 373.8724
# ----------
# epoch 43/100
# 1/295, train_loss: 0.1913, step time: 1.1095
# 2/295, train_loss: 0.1429, step time: 1.0576
# 3/295, train_loss: 0.0673, step time: 1.1008
# 4/295, train_loss: 0.0848, step time: 1.0544
# 5/295, train_loss: 0.0715, step time: 1.0321
# 6/295, train_loss: 0.1700, step time: 1.0634
# 7/295, train_loss: 0.0723, step time: 1.0551
# 8/295, train_loss: 0.1033, step time: 1.0503
# 9/295, train_loss: 0.0626, step time: 1.0315
# 10/295, train_loss: 0.1033, step time: 1.0408
# 11/295, train_loss: 0.0746, step time: 1.0444
# 12/295, train_loss: 0.1463, step time: 1.0935
# 13/295, train_loss: 0.1179, step time: 1.0420
# 14/295, train_loss: 0.0947, step time: 1.0371
# 15/295, train_loss: 0.1644, step time: 1.0414
# 16/295, train_loss: 0.0732, step time: 1.0519
# 17/295, train_loss: 0.0856, step time: 1.0671
# 18/295, train_loss: 0.0844, step time: 1.0380
# 19/295, train_loss: 0.0461, step time: 1.0298
# 20/295, train_loss: 0.0921, step time: 1.0324
# 21/295, train_loss: 0.0484, step time: 1.0321
# 22/295, train_loss: 0.0637, step time: 1.0379
# 23/295, train_loss: 0.1109, step time: 1.0501
# 24/295, train_loss: 0.1170, step time: 1.0548
# 25/295, train_loss: 0.1220, step time: 1.1154
# 26/295, train_loss: 0.0929, step time: 1.0367
# 27/295, train_loss: 0.1140, step time: 1.0473
# 28/295, train_loss: 0.0606, step time: 1.0659
# 29/295, train_loss: 0.1413, step time: 1.0875
# 30/295, train_loss: 0.2073, step time: 1.1141
# 31/295, train_loss: 0.1281, step time: 1.0429
# 32/295, train_loss: 0.0537, step time: 1.1179
# 33/295, train_loss: 0.0775, step time: 1.0735
# 34/295, train_loss: 0.1229, step time: 1.0688
# 35/295, train_loss: 0.0682, step time: 1.0504
# 36/295, train_loss: 0.0790, step time: 1.0342
# 37/295, train_loss: 0.0685, step time: 1.0492
# 38/295, train_loss: 0.2350, step time: 1.0461
# 39/295, train_loss: 0.1752, step time: 1.0423
# 40/295, train_loss: 0.0505, step time: 1.1044
# 41/295, train_loss: 0.1615, step time: 1.0355
# 42/295, train_loss: 0.1308, step time: 1.0524
# 43/295, train_loss: 0.2748, step time: 1.0325
# 44/295, train_loss: 0.3909, step time: 1.0877
# 45/295, train_loss: 0.0768, step time: 1.0341
# 46/295, train_loss: 0.1458, step time: 1.0394
# 47/295, train_loss: 0.1296, step time: 1.0334
# 48/295, train_loss: 0.3126, step time: 1.0339
# 49/295, train_loss: 0.0891, step time: 1.0416
# 50/295, train_loss: 0.0715, step time: 1.0532
# 51/295, train_loss: 0.0679, step time: 1.0347
# 52/295, train_loss: 0.0776, step time: 1.0392
# 53/295, train_loss: 0.1023, step time: 1.0557
# 54/295, train_loss: 0.0702, step time: 1.0464
# 55/295, train_loss: 0.1477, step time: 1.0587
# 56/295, train_loss: 0.5276, step time: 1.0418
# 57/295, train_loss: 0.1217, step time: 1.0570
# 58/295, train_loss: 0.0457, step time: 1.0336
# 59/295, train_loss: 0.0874, step time: 1.0773
# 60/295, train_loss: 0.1261, step time: 1.0379
# 61/295, train_loss: 0.0711, step time: 1.0341
# 62/295, train_loss: 0.0738, step time: 1.0512
# 63/295, train_loss: 0.1467, step time: 1.0365
# 64/295, train_loss: 0.1510, step time: 1.0580
# 65/295, train_loss: 0.2331, step time: 1.0355
# 66/295, train_loss: 0.0563, step time: 1.0487
# 67/295, train_loss: 0.1023, step time: 1.0780
# 68/295, train_loss: 0.0685, step time: 1.0398
# 69/295, train_loss: 0.1795, step time: 1.0388
# 70/295, train_loss: 0.0584, step time: 1.0400
# 71/295, train_loss: 0.1892, step time: 1.0708
# 72/295, train_loss: 0.0568, step time: 1.0455
# 73/295, train_loss: 0.3388, step time: 1.0350
# 74/295, train_loss: 0.1156, step time: 1.0368
# 75/295, train_loss: 0.0575, step time: 1.0423
# 76/295, train_loss: 0.0546, step time: 1.0372
# 77/295, train_loss: 0.3848, step time: 1.0430
# 78/295, train_loss: 0.0859, step time: 1.0493
# 79/295, train_loss: 0.1380, step time: 1.0388
# 80/295, train_loss: 0.2682, step time: 1.0574
# 81/295, train_loss: 0.0776, step time: 1.0555
# 82/295, train_loss: 0.0881, step time: 1.0564
# 83/295, train_loss: 0.1644, step time: 1.1913
# 84/295, train_loss: 0.1054, step time: 1.0372
# 85/295, train_loss: 0.3944, step time: 1.0347
# 86/295, train_loss: 0.0505, step time: 1.0393
# 87/295, train_loss: 0.0646, step time: 1.0483
# 88/295, train_loss: 0.0768, step time: 1.0349
# 89/295, train_loss: 0.0533, step time: 1.0620
# 90/295, train_loss: 0.1190, step time: 1.0449
# 91/295, train_loss: 0.4154, step time: 1.0356
# 92/295, train_loss: 0.0769, step time: 1.0378
# 93/295, train_loss: 0.1081, step time: 1.0593
# 94/295, train_loss: 0.0501, step time: 1.0488
# 95/295, train_loss: 0.1248, step time: 1.0571
# 96/295, train_loss: 0.1197, step time: 1.0367
# 97/295, train_loss: 0.0643, step time: 1.0392
# 98/295, train_loss: 0.4430, step time: 1.0357
# 99/295, train_loss: 0.1160, step time: 1.0354
# 100/295, train_loss: 0.2047, step time: 1.0390
# 101/295, train_loss: 0.1136, step time: 1.0361
# 102/295, train_loss: 0.0676, step time: 1.0328
# 103/295, train_loss: 0.0806, step time: 1.0526
# 104/295, train_loss: 0.0945, step time: 1.0663
# 105/295, train_loss: 0.0455, step time: 1.0400
# 106/295, train_loss: 0.1028, step time: 1.0316
# 107/295, train_loss: 0.4319, step time: 1.0429
# 108/295, train_loss: 0.1022, step time: 1.0599
# 109/295, train_loss: 0.0990, step time: 1.0421
# 110/295, train_loss: 0.1512, step time: 1.0401
# 111/295, train_loss: 0.2553, step time: 1.0708
# 112/295, train_loss: 0.1722, step time: 1.0344
# 113/295, train_loss: 0.1550, step time: 1.0422
# 114/295, train_loss: 0.1755, step time: 1.0448
# 115/295, train_loss: 0.0961, step time: 1.1100
# 116/295, train_loss: 0.1136, step time: 1.0672
# 117/295, train_loss: 0.1452, step time: 1.0329
# 118/295, train_loss: 0.1168, step time: 1.0436
# 119/295, train_loss: 0.1013, step time: 1.0389
# 120/295, train_loss: 0.0497, step time: 1.0401
# 121/295, train_loss: 0.1008, step time: 1.0374
# 122/295, train_loss: 0.0476, step time: 1.0700
# 123/295, train_loss: 0.0880, step time: 1.0742
# 124/295, train_loss: 0.1430, step time: 1.0342
# 125/295, train_loss: 0.0647, step time: 1.0639
# 126/295, train_loss: 0.1493, step time: 1.0348
# 127/295, train_loss: 0.4157, step time: 1.0772
# 128/295, train_loss: 0.0518, step time: 1.0440
# 129/295, train_loss: 0.4402, step time: 1.0708
# 130/295, train_loss: 0.1047, step time: 1.0380
# 131/295, train_loss: 0.1370, step time: 1.0527
# 132/295, train_loss: 0.1049, step time: 1.0427
# 133/295, train_loss: 0.1646, step time: 1.0664
# 134/295, train_loss: 0.1169, step time: 1.0881
# 135/295, train_loss: 0.0647, step time: 1.0910
# 136/295, train_loss: 0.0812, step time: 1.0382
# 137/295, train_loss: 0.1238, step time: 1.0389
# 138/295, train_loss: 0.1063, step time: 1.0578
# 139/295, train_loss: 0.0509, step time: 1.0320
# 140/295, train_loss: 0.3098, step time: 1.0518
# 141/295, train_loss: 0.0991, step time: 1.0553
# 142/295, train_loss: 0.1740, step time: 1.1682
# 143/295, train_loss: 0.0803, step time: 1.0337
# 144/295, train_loss: 0.0891, step time: 1.0421
# 145/295, train_loss: 0.0943, step time: 1.0415
# 146/295, train_loss: 0.0818, step time: 1.0363
# 147/295, train_loss: 0.1912, step time: 1.0476
# 148/295, train_loss: 0.0955, step time: 1.0313
# 149/295, train_loss: 0.0765, step time: 1.0443
# 150/295, train_loss: 0.4211, step time: 1.0543
# 151/295, train_loss: 0.0461, step time: 1.0364
# 152/295, train_loss: 0.4101, step time: 1.0362
# 153/295, train_loss: 0.0779, step time: 1.0356
# 154/295, train_loss: 0.2063, step time: 1.0427
# 155/295, train_loss: 0.4229, step time: 1.0312
# 156/295, train_loss: 0.0533, step time: 1.0760
# 157/295, train_loss: 0.2143, step time: 1.0321
# 158/295, train_loss: 0.0856, step time: 1.0323
# 159/295, train_loss: 0.0607, step time: 1.0404
# 160/295, train_loss: 0.1493, step time: 1.0349
# 161/295, train_loss: 0.1520, step time: 1.0583
# 162/295, train_loss: 0.0682, step time: 1.0363
# 163/295, train_loss: 0.3096, step time: 1.0440
# 164/295, train_loss: 0.3903, step time: 1.0356
# 165/295, train_loss: 0.0570, step time: 1.0378
# 166/295, train_loss: 0.0851, step time: 1.0426
# 167/295, train_loss: 0.0437, step time: 1.0426
# 168/295, train_loss: 0.0781, step time: 1.0409
# 169/295, train_loss: 0.0952, step time: 1.0489
# 170/295, train_loss: 0.1032, step time: 1.0440
# 171/295, train_loss: 0.0315, step time: 1.0307
# 172/295, train_loss: 0.0873, step time: 1.0915
# 173/295, train_loss: 0.1939, step time: 1.0687
# 174/295, train_loss: 0.1239, step time: 1.0384
# 175/295, train_loss: 0.0895, step time: 1.0363
# 176/295, train_loss: 0.0787, step time: 1.0750
# 177/295, train_loss: 0.0405, step time: 1.0445
# 178/295, train_loss: 0.0750, step time: 1.0363
# 179/295, train_loss: 0.0968, step time: 1.0326
# 180/295, train_loss: 0.0545, step time: 1.0808
# 181/295, train_loss: 0.1247, step time: 1.0398
# 182/295, train_loss: 0.0693, step time: 1.0644
# 183/295, train_loss: 0.0504, step time: 1.0717
# 184/295, train_loss: 0.0792, step time: 1.0379
# 185/295, train_loss: 0.1158, step time: 1.0374
# 186/295, train_loss: 0.1367, step time: 1.0342
# 187/295, train_loss: 0.0935, step time: 1.0331
# 188/295, train_loss: 0.0997, step time: 1.0597
# 189/295, train_loss: 0.1211, step time: 1.0488
# 190/295, train_loss: 0.0948, step time: 1.0511
# 191/295, train_loss: 0.0514, step time: 1.0460
# 192/295, train_loss: 0.0830, step time: 1.0582
# 193/295, train_loss: 0.0766, step time: 1.0402
# 194/295, train_loss: 0.0536, step time: 1.1108
# 195/295, train_loss: 0.1735, step time: 1.0734
# 196/295, train_loss: 0.0698, step time: 1.0601
# 197/295, train_loss: 0.1279, step time: 1.0343
# 198/295, train_loss: 0.4376, step time: 1.0386
# 199/295, train_loss: 0.1858, step time: 1.0648
# 200/295, train_loss: 0.0832, step time: 1.0400
# 201/295, train_loss: 0.0783, step time: 1.0785
# 202/295, train_loss: 0.1142, step time: 1.0496
# 203/295, train_loss: 0.0870, step time: 1.0339
# 204/295, train_loss: 0.0823, step time: 1.0358
# 205/295, train_loss: 0.0553, step time: 1.0323
# 206/295, train_loss: 0.1393, step time: 1.0619
# 207/295, train_loss: 0.1210, step time: 1.0364
# 208/295, train_loss: 0.0426, step time: 1.0406
# 209/295, train_loss: 0.0447, step time: 1.0876
# 210/295, train_loss: 0.1023, step time: 1.0347
# 211/295, train_loss: 0.0603, step time: 1.0605
# 212/295, train_loss: 0.1390, step time: 1.1473
# 213/295, train_loss: 0.0807, step time: 1.0567
# 214/295, train_loss: 0.0525, step time: 1.0356
# 215/295, train_loss: 0.1032, step time: 1.0381
# 216/295, train_loss: 0.0916, step time: 1.0503
# 217/295, train_loss: 0.1364, step time: 1.0432
# 218/295, train_loss: 0.4295, step time: 1.0444
# 219/295, train_loss: 0.1107, step time: 1.0454
# 220/295, train_loss: 0.0499, step time: 1.0356
# 221/295, train_loss: 0.3845, step time: 1.0333
# 222/295, train_loss: 0.1092, step time: 1.0336
# 223/295, train_loss: 0.0674, step time: 1.0360
# 224/295, train_loss: 0.0990, step time: 1.0627
# 225/295, train_loss: 0.0599, step time: 1.0412
# 226/295, train_loss: 0.0846, step time: 1.0332
# 227/295, train_loss: 0.0462, step time: 1.0627
# 228/295, train_loss: 0.1067, step time: 1.0371
# 229/295, train_loss: 0.1902, step time: 1.0374
# 230/295, train_loss: 0.0967, step time: 1.0383
# 231/295, train_loss: 0.1765, step time: 1.0370
# 232/295, train_loss: 0.3915, step time: 1.0837
# 233/295, train_loss: 0.1092, step time: 1.0408
# 234/295, train_loss: 0.0879, step time: 1.0391
# 235/295, train_loss: 0.1312, step time: 1.0486
# 236/295, train_loss: 0.2798, step time: 1.0869
# 237/295, train_loss: 0.1310, step time: 1.0429
# 238/295, train_loss: 0.1281, step time: 1.0714
# 239/295, train_loss: 0.1201, step time: 1.1180
# 240/295, train_loss: 0.0645, step time: 1.0372
# 241/295, train_loss: 0.0817, step time: 1.0380
# 242/295, train_loss: 0.4289, step time: 1.0524
# 243/295, train_loss: 0.1388, step time: 1.0364
# 244/295, train_loss: 0.2330, step time: 1.0399
# 245/295, train_loss: 0.0583, step time: 1.0373
# 246/295, train_loss: 0.1278, step time: 1.0607
# 247/295, train_loss: 0.2034, step time: 1.0842
# 248/295, train_loss: 0.1290, step time: 1.0334
# 249/295, train_loss: 0.1525, step time: 1.0353
# 250/295, train_loss: 0.0535, step time: 1.0397
# 251/295, train_loss: 0.4550, step time: 1.0441
# 252/295, train_loss: 0.0531, step time: 1.0609
# 253/295, train_loss: 0.0701, step time: 1.0313
# 254/295, train_loss: 0.0948, step time: 1.0329
# 255/295, train_loss: 0.1902, step time: 1.0417
# 256/295, train_loss: 0.1599, step time: 1.0352
# 257/295, train_loss: 0.5321, step time: 1.0322
# 258/295, train_loss: 0.0478, step time: 1.0382
# 259/295, train_loss: 0.1663, step time: 1.0349
# 260/295, train_loss: 0.2423, step time: 1.0448
# 261/295, train_loss: 0.0840, step time: 1.0579
# 262/295, train_loss: 0.1742, step time: 1.0588
# 263/295, train_loss: 0.0824, step time: 1.0421
# 264/295, train_loss: 0.0739, step time: 1.0370
# 265/295, train_loss: 0.0671, step time: 1.0305
# 266/295, train_loss: 0.1457, step time: 1.0357
# 267/295, train_loss: 0.0414, step time: 1.1059
# 268/295, train_loss: 0.0601, step time: 1.0583
# 269/295, train_loss: 0.1860, step time: 1.0322
# 270/295, train_loss: 0.0694, step time: 1.0573
# 271/295, train_loss: 0.4183, step time: 1.0562
# 272/295, train_loss: 0.1329, step time: 1.0787
# 273/295, train_loss: 0.0533, step time: 1.0396
# 274/295, train_loss: 0.0696, step time: 1.0383
# 275/295, train_loss: 0.1331, step time: 1.0355
# 276/295, train_loss: 0.1504, step time: 1.0428
# 277/295, train_loss: 0.0600, step time: 1.0414
# 278/295, train_loss: 0.2482, step time: 1.0640
# 279/295, train_loss: 0.0698, step time: 1.0348
# 280/295, train_loss: 0.0679, step time: 1.0380
# 281/295, train_loss: 0.2145, step time: 1.0702
# 282/295, train_loss: 0.3815, step time: 1.0342
# 283/295, train_loss: 0.0812, step time: 1.0339
# 284/295, train_loss: 0.0783, step time: 1.0308
# 285/295, train_loss: 0.1151, step time: 1.0607
# 286/295, train_loss: 0.0660, step time: 1.0357
# 287/295, train_loss: 0.0849, step time: 1.0328
# 288/295, train_loss: 0.1125, step time: 1.0289
# 289/295, train_loss: 0.2029, step time: 1.0297
# 290/295, train_loss: 0.1271, step time: 1.0281
# 291/295, train_loss: 0.4071, step time: 1.0299
# 292/295, train_loss: 0.3753, step time: 1.0292
# 293/295, train_loss: 0.4230, step time: 1.0283
# 294/295, train_loss: 0.1643, step time: 1.0290
# 295/295, train_loss: 0.1461, step time: 1.0282
# epoch 43 average loss: 0.1366
# current epoch: 43 current mean dice: 0.7603 tc: 0.6928 wt: 0.8561 et: 0.7324
# best mean dice: 0.7814 at epoch: 13
# time consuming of epoch 43 is: 379.8379
# Training process is stopped early....

# %%
print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_metric_epoch}, total time: {total_time}.")
# Out:
# train completed, best_metric: 0.7814 at epoch: 13, total time: 16342.622815608978.

# %% [markdown]
# # Dice + CCE loss

# %% [markdown]
# # Plot the loss and metric

# %%
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y, color="red")
plt.subplot(1, 2, 2)
plt.title("Val Mean Dice")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y, color="green")
plt.show()

plt.figure("train", (18, 6))
plt.subplot(1, 3, 1)
plt.title("Val Mean Dice TC")
x = [val_interval * (i + 1) for i in range(len(metric_values_tc))]
y = metric_values_tc
plt.xlabel("epoch")
plt.plot(x, y, color="blue")
plt.subplot(1, 3, 2)
plt.title("Val Mean Dice WT")
x = [val_interval * (i + 1) for i in range(len(metric_values_wt))]
y = metric_values_wt
plt.xlabel("epoch")
plt.plot(x, y, color="brown")
plt.subplot(1, 3, 3)
plt.title("Val Mean Dice ET")
x = [val_interval * (i + 1) for i in range(len(metric_values_et))]
y = metric_values_et
plt.xlabel("epoch")
plt.plot(x, y, color="purple")
plt.show()

# %% [markdown]
# # Check best model output with the input image and label

# %%
model.load_state_dict(torch.load(os.path.join(output_dir, "best_metric_model.pth")))
model.eval()
                      
with torch.no_grad():
    # select one image to evaluate and visualize the model output
    val_data = val_ds[40]
    val_input = val_data["image"].unsqueeze(0).to(device)
    val_output = inference(val_input)
    val_output = post_trans(val_output[0])
    plt.figure("image", (24, 6))
    for i in range(4):
        plt.subplot(1, 4, i + 1)
        plt.title(f"image channel {i}")
        plt.imshow(val_data["image"][i, :, :, val_input.shape[-1] // 2].detach().cpu(), cmap="gray")
    plt.show()
    
    # visualize the 3 channels label corresponding to this image
    plt.figure("label", (18, 6))
    for i in range(3):
        plt.subplot(1, 3, i + 1)
        plt.title(f"label channel {i}")
        plt.imshow(val_data["label"][i, :, :, val_input.shape[-1] // 2].detach().cpu())
    plt.show()
    # visualize the 3 channels model output corresponding to this image
    plt.figure("output", (18, 6))
    for i in range(3):
        plt.subplot(1, 3, i + 1)
        plt.title(f"output channel {i}")
        plt.imshow(val_output[i, :, :, val_input.shape[-1] // 2].detach().cpu())
    plt.show()

# %% [markdown]
# # Evaluation on test image

# %%
transform = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image"]),
        EnsureTyped(keys=["image", "label"]),
        ConvertToMultiChannelBasedOnBratsClassesd(keys="label"),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(
            keys=["image", "label"],
            pixdim=(1.0, 1.0, 1.0),
            mode=["bilinear", "nearest"]
        ),
        Resized(keys=["image", "label"], spatial_size=cfg.unetr.img_shape, mode="nearest"),
        NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
        ToTensord(keys=["image", "label"]),
    ]
)

test_ds = BratsDataset(
    root_dir=root_dir,
    section="test",
    transform=transform,
    cache_num=0
)
test_loader = DataLoader(test_ds, batch_size=1, shuffle=False, num_workers=4)

# %%
model.load_state_dict(torch.load(os.path.join(output_dir, "best_metric_model.pth")))
model.eval()

with torch.no_grad():
    for test_data in test_loader:
        test_inputs, test_labels = (
            test_data["image"].to(device),
            test_data["label"].to(device),
        )
        test_outputs = inference(test_inputs)
        test_outputs = [post_trans(i) for i in decollate_batch(test_outputs)]
        dice_metric(y_pred=test_outputs, y=test_labels)
        dice_metric_batch(y_pred=test_outputs, y=test_labels)

    metric = dice_metric.aggregate().item()
    metric_batch = dice_metric_batch.aggregate()

    dice_metric.reset()
    dice_metric_batch.reset()

metric_tc, metric_wt, metric_et = metric_batch[0].item(), metric_batch[1].item(), metric_batch[2].item()

print("Metric on test image: ", metric)
print(f"metric_tc: {metric_tc:.4f}")
print(f"metric_wt: {metric_wt:.4f}")
print(f"metric_et: {metric_et:.4f}")
# Out:
# Metric on test image:  0.722220778465271
# metric_tc: 0.6743
# metric_wt: 0.8194
# metric_et: 0.6852
